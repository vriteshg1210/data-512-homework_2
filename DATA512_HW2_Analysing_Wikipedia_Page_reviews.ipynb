# %% [markdown]
# <a href="https://colab.research.google.com/github/vriteshg1210/data-512-homework_2/blob/main/DATA512_HW2_Analysing_Wikipedia_Page_reviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DATA512 - HW2: Considering Bias in Data
# by Vritesh Gera, University of Washington

# %% [markdown]
# The goal of this project is to explore the concept of bias in data using Wikipedia articles. We will consider articles about cities in different US states and will combine a dataset of Wikipedia articles with a dataset of state populations, and use a machine learning service called ORES to estimate the quality of the articles about the cities. We will perform an analysis of how the coverage of US cities on Wikipedia and how the quality of articles about cities varies among states. The Wikipedia ['Category:Lists of cities in the United States by state'](https://en.wikipedia.org/wiki/Category:Lists_of_cities_in_the_United_States_by_state) is crawled to generate a list of Wikipedia article pages about US cities from each state. This data can be found in [us_cities_by_state_SEPT.2023.csv](https://drive.google.com/file/d/1khouDmMaZyKo0y5WkFj4lu7g8o35x_98/view?usp=sharing).

# %% [markdown]
# ## Data Acquisition

# %% [markdown]
# We will start by acquiring the Page info data using the API mentioned above and creating list of dictionaries and finally dataframes of this data. The first step will be importing the python libraries which are necessary to run this program.

# %%
# These are standard python modules
import json, time, urllib.parse
import pandas as pd
import matplotlib.pyplot as plt
import warnings

# The 'requests' module is not a standard Python module. You will need to install this with pip/pip3 if you do not already have it
import requests

# %% [markdown]
# I have uploaded the dataset to my Google drive and hence to access it, we will have to mount the driver in google colab. You can find the dataset here-https://drive.google.com/file/d/1df_fvJXuFtZGuYUpqitDYj2RWkkPbKOv/view?usp=drive_link

# %%
# Suppress the warning statements
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Page Info API
# The code below illustrates how to access page info data using the [MediaWiki REST API for the EN Wikipedia](https://www.mediawiki.org/wiki/API:Main_page). It shows how to request summary 'page info' for a single article page. The API documentation, [API:Info](), covers additional details that may be helpful when trying to use or understand this example. The code provided below has been sampled from [this notebook](https://drive.google.com/file/d/15UoE16s-IccCTOXREjU3xDIz07tlpyrl/view?usp=sharing) under the [CC-BY license](https://creativecommons.org/licenses/by/4.0/).

# %% [markdown]
# We will now be using the API for getting the Page Info data from Wikipedia. Below are some constants that help make the code a bit more readable and makes the calling of the API smoother.

# %%
#    CONSTANTS

# The basic English Wikipedia API endpoint
API_ENWIKIPEDIA_ENDPOINT = "https://en.wikipedia.org/w/api.php"

# We'll assume that there needs to be some throttling for these requests - we should always be nice to a free data resource
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

# When making automated requests we should include something that is unique to the person making the request
# This should include an email - your UW email would be good to put in there
REQUEST_HEADERS = {
    'User-Agent': '<vriteshg@uw.edu>, University of Washington, MSDS DATA 512 - AUTUMN 2023',
}

#Now we will access the list of article urls along with the state and the title of the article stored in a csv
df_city_by_state = pd.read_csv('/content/drive/My Drive/us_cities_by_state_SEPT.2023.csv')
ARTICLE_TITLES = df_city_by_state['page_title'].values

# This is a string of additional page properties that can be returned see the Info documentation for
# what can be included. If you don't want any this can simply be the empty string
PAGEINFO_EXTENDED_PROPERTIES = "talkid|url|watched|watchers"
#PAGEINFO_EXTENDED_PROPERTIES = ""

# This template lists the basic parameters for making this
PAGEINFO_PARAMS_TEMPLATE = {
    "action": "query",
    "format": "json",
    "titles": "",           # to simplify this should be a single page title at a time
    "prop": "info",
    "inprop": PAGEINFO_EXTENDED_PROPERTIES
}

# %% [markdown]
# The API request will be made using one procedure. The idea is to make this reusable. The procedure is parameterized, but relies on the constants above for the important parameters. The underlying assumption is that this will be used to request data for a set of article pages. Therefore the parameter most likely to change is the article_title.

# %%
#    PROCEDURES/FUNCTIONS

def request_pageinfo_per_article(article_title = None,
                                 endpoint_url = API_ENWIKIPEDIA_ENDPOINT,
                                 request_template = PAGEINFO_PARAMS_TEMPLATE,
                                 headers = REQUEST_HEADERS):

    # article title can be as a parameter to the call or in the request_template
    if article_title:
        request_template['titles'] = article_title

    if not request_template['titles']:
        raise Exception("Must supply an article title to make a pageinfo request.")

    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free
        # data source like Wikipedia - or any other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(endpoint_url, headers=headers, params=request_template)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %% [markdown]
# Now we will hit the API and start appending the data being sent back for each article in a list. In the end we'll have a list of dictionaries.

# %%
article_info_list = []
for i in range(0,len(ARTICLE_TITLES)):
  print(f"Getting page info data for: {ARTICLE_TITLES[i]}")
  info = request_pageinfo_per_article(ARTICLE_TITLES[i])
  article_info_list.append(info)
# Out:
# Getting page info data for: Abbeville, Alabama
# Getting page info data for: Adamsville, Alabama
# Getting page info data for: Addison, Alabama
# Getting page info data for: Akron, Alabama
# Getting page info data for: Alabaster, Alabama
# Getting page info data for: Albertville, Alabama
# Getting page info data for: Alexander City, Alabama
# Getting page info data for: Aliceville, Alabama
# Getting page info data for: Allgood, Alabama
# Getting page info data for: Altoona, Alabama
# Getting page info data for: Andalusia, Alabama
# Getting page info data for: Anderson, Lauderdale County, Alabama
# Getting page info data for: Anniston, Alabama
# Getting page info data for: Arab, Alabama
# Getting page info data for: Ardmore, Alabama
# Getting page info data for: Argo, Alabama
# Getting page info data for: Ariton, Alabama
# Getting page info data for: Arley, Alabama
# Getting page info data for: Ashford, Alabama
# Getting page info data for: Ashland, Alabama
# Getting page info data for: Ashville, Alabama
# Getting page info data for: Athens, Alabama
# Getting page info data for: Atmore, Alabama
# Getting page info data for: Attalla, Alabama
# Getting page info data for: Auburn, Alabama
# Getting page info data for: Autaugaville, Alabama
# Getting page info data for: Avon, Alabama
# Getting page info data for: Babbie, Alabama
# Getting page info data for: Baileyton, Alabama
# Getting page info data for: Bakerhill, Alabama
# Getting page info data for: Banks, Alabama
# Getting page info data for: Bay Minette, Alabama
# Getting page info data for: Bayou La Batre, Alabama
# Getting page info data for: Bear Creek, Alabama
# Getting page info data for: Beatrice, Alabama
# Getting page info data for: Beaverton, Alabama
# Getting page info data for: Belk, Alabama
# Getting page info data for: Benton, Alabama
# Getting page info data for: Berlin, Alabama
# Getting page info data for: Berry, Alabama
# Getting page info data for: Bessemer, Alabama
# Getting page info data for: Billingsley, Alabama
# Getting page info data for: Birmingham, Alabama
# Getting page info data for: Black, Alabama
# Getting page info data for: Blountsville, Alabama
# Getting page info data for: Blue Springs, Alabama
# Getting page info data for: Boaz, Alabama
# Getting page info data for: Boligee, Alabama
# Getting page info data for: Bon Air, Alabama
# Getting page info data for: Brantley, Alabama
# Getting page info data for: Brent, Alabama
# Getting page info data for: Brewton, Alabama
# Getting page info data for: Bridgeport, Alabama
# Getting page info data for: Brighton, Alabama
# Getting page info data for: Brilliant, Alabama
# Getting page info data for: Brookside, Alabama
# Getting page info data for: Brookwood, Alabama
# Getting page info data for: Brundidge, Alabama
# Getting page info data for: Butler, Alabama
# Getting page info data for: Calera, Alabama
# Getting page info data for: Camden, Alabama
# Getting page info data for: Camp Hill, Alabama
# Getting page info data for: Carbon Hill, Alabama
# Getting page info data for: Cardiff, Alabama
# Getting page info data for: Carolina, Alabama
# Getting page info data for: Carrollton, Alabama
# Getting page info data for: Castleberry, Alabama
# Getting page info data for: Cedar Bluff, Alabama
# Getting page info data for: Center Point, Alabama
# Getting page info data for: Centre, Alabama
# Getting page info data for: Centreville, Alabama
# Getting page info data for: Chatom, Alabama
# Getting page info data for: Chelsea, Alabama
# Getting page info data for: Cherokee, Alabama
# Getting page info data for: Chickasaw, Alabama
# Getting page info data for: Childersburg, Alabama
# Getting page info data for: Citronelle, Alabama
# Getting page info data for: Clanton, Alabama
# Getting page info data for: Clay, Alabama
# Getting page info data for: Clayhatchee, Alabama
# Getting page info data for: Clayton, Alabama
# Getting page info data for: Cleveland, Alabama
# Getting page info data for: Clio, Alabama
# Getting page info data for: Coaling, Alabama
# Getting page info data for: Coffee Springs, Alabama
# Getting page info data for: Coffeeville, Alabama
# Getting page info data for: Coker, Alabama
# Getting page info data for: Collinsville, Alabama
# Getting page info data for: Colony, Alabama
# Getting page info data for: Columbia, Alabama
# Getting page info data for: Columbiana, Alabama
# Getting page info data for: Coosada, Alabama
# Getting page info data for: Cordova, Alabama
# Getting page info data for: Cottonwood, Alabama
# Getting page info data for: County Line, Alabama
# Getting page info data for: Courtland, Alabama
# Getting page info data for: Cowarts, Alabama
# Getting page info data for: Creola, Alabama
# Getting page info data for: Crossville, Alabama
# Getting page info data for: Cuba, Alabama
# Getting page info data for: Cullman, Alabama
# Getting page info data for: Cusseta, Alabama
# Getting page info data for: Dadeville, Alabama
# Getting page info data for: Daleville, Alabama
# Getting page info data for: Daphne, Alabama
# Getting page info data for: Dauphin Island, Alabama
# Getting page info data for: Daviston, Alabama
# Getting page info data for: Dayton, Alabama
# Getting page info data for: Deatsville, Alabama
# Getting page info data for: Decatur, Alabama
# Getting page info data for: Demopolis, Alabama
# Getting page info data for: Detroit, Alabama
# Getting page info data for: Dodge City, Alabama
# Getting page info data for: Dora, Alabama
# Getting page info data for: Dothan, Alabama
# Getting page info data for: Double Springs, Alabama
# Getting page info data for: Douglas, Alabama
# Getting page info data for: Dozier, Alabama
# Getting page info data for: Dutton, Alabama
# Getting page info data for: East Brewton, Alabama
# Getting page info data for: Eclectic, Alabama
# Getting page info data for: Edwardsville, Alabama
# Getting page info data for: Elba, Alabama
# Getting page info data for: Elberta, Alabama
# Getting page info data for: Eldridge, Alabama
# Getting page info data for: Elkmont, Alabama
# Getting page info data for: Elmore, Alabama
# Getting page info data for: Emelle, Alabama
# Getting page info data for: Enterprise, Alabama
# Getting page info data for: Epes, Alabama
# Getting page info data for: Ethelsville, Alabama
# Getting page info data for: Eufaula, Alabama
# Getting page info data for: Eutaw, Alabama
# Getting page info data for: Eva, Alabama
# Getting page info data for: Evergreen, Conecuh County, Alabama
# Getting page info data for: Excel, Alabama
# Getting page info data for: Fairfield, Alabama
# Getting page info data for: Fairhope, Alabama
# Getting page info data for: Fairview, Alabama
# Getting page info data for: Falkville, Alabama
# Getting page info data for: Faunsdale, Alabama
# Getting page info data for: Fayette, Alabama
# Getting page info data for: Five Points, Alabama
# Getting page info data for: Flomaton, Alabama
# Getting page info data for: Florala, Alabama
# Getting page info data for: Florence, Alabama
# Getting page info data for: Foley, Alabama
# Getting page info data for: Forkland, Alabama
# Getting page info data for: Fort Deposit, Alabama
# Getting page info data for: Fort Payne, Alabama
# Getting page info data for: Franklin, Alabama
# Getting page info data for: Frisco City, Alabama
# Getting page info data for: Fruithurst, Alabama
# Getting page info data for: Fulton, Alabama
# Getting page info data for: Fultondale, Alabama
# Getting page info data for: Fyffe, Alabama
# Getting page info data for: Gadsden, Alabama
# Getting page info data for: Gainesville, Alabama
# Getting page info data for: Gantt, Alabama
# Getting page info data for: Garden City, Alabama
# Getting page info data for: Gardendale, Alabama
# Getting page info data for: Gaylesville, Alabama
# Getting page info data for: Geiger, Alabama
# Getting page info data for: Geneva, Alabama
# Getting page info data for: Georgiana, Alabama
# Getting page info data for: Geraldine, Alabama
# Getting page info data for: Gilbertown, Alabama
# Getting page info data for: Glen Allen, Alabama
# Getting page info data for: Glencoe, Alabama
# Getting page info data for: Glenwood, Alabama
# Getting page info data for: Goldville, Alabama
# Getting page info data for: Good Hope, Alabama
# Getting page info data for: Goodwater, Alabama
# Getting page info data for: Gordo, Alabama
# Getting page info data for: Gordon, Alabama
# Getting page info data for: Gordonville, Alabama
# Getting page info data for: Goshen, Alabama
# Getting page info data for: Grant, Alabama
# Getting page info data for: Graysville, Alabama
# Getting page info data for: Greensboro, Alabama
# Getting page info data for: Greenville, Alabama
# Getting page info data for: Grimes, Alabama
# Getting page info data for: Grove Hill, Alabama
# Getting page info data for: Guin, Alabama
# Getting page info data for: Gulf Shores, Alabama
# Getting page info data for: Guntersville, Alabama
# Getting page info data for: Gurley, Alabama
# Getting page info data for: Gu-Win, Alabama
# Getting page info data for: Hackleburg, Alabama
# Getting page info data for: Haleburg, Alabama
# Getting page info data for: Haleyville, Alabama
# Getting page info data for: Hamilton, Alabama
# Getting page info data for: Hammondville, Alabama
# Getting page info data for: Hanceville, Alabama
# Getting page info data for: Harpersville, Alabama
# Getting page info data for: Hartford, Alabama
# Getting page info data for: Hartselle, Alabama
# Getting page info data for: Hayden, Alabama
# Getting page info data for: Hayneville, Alabama
# Getting page info data for: Headland, Alabama
# Getting page info data for: Heath, Alabama
# Getting page info data for: Heflin, Alabama
# Getting page info data for: Helena, Alabama
# Getting page info data for: Henagar, Alabama
# Getting page info data for: Highland Lake, Alabama
# Getting page info data for: Hillsboro, Alabama
# Getting page info data for: Hobson City, Alabama
# Getting page info data for: Hodges, Alabama
# Getting page info data for: Hokes Bluff, Alabama
# Getting page info data for: Holly Pond, Alabama
# Getting page info data for: Hollywood, Alabama
# Getting page info data for: Homewood, Alabama
# Getting page info data for: Hoover, Alabama
# Getting page info data for: Horn Hill, Alabama
# Getting page info data for: Hueytown, Alabama
# Getting page info data for: Huntsville, Alabama
# Getting page info data for: Hurtsboro, Alabama
# Getting page info data for: Hytop, Alabama
# Getting page info data for: Ider, Alabama
# Getting page info data for: Indian Springs Village, Alabama
# Getting page info data for: Irondale, Alabama
# Getting page info data for: Jackson, Alabama
# Getting page info data for: Jackson's Gap, Alabama
# Getting page info data for: Jacksonville, Alabama
# Getting page info data for: Jasper, Alabama
# Getting page info data for: Jemison, Alabama
# Getting page info data for: Kansas, Alabama
# Getting page info data for: Kellyton, Alabama
# Getting page info data for: Kennedy, Alabama
# Getting page info data for: Killen, Alabama
# Getting page info data for: Kimberly, Alabama
# Getting page info data for: Kinsey, Alabama
# Getting page info data for: Kinston, Alabama
# Getting page info data for: LaFayette, Alabama
# Getting page info data for: Lake View, Alabama
# Getting page info data for: Lakeview, Alabama
# Getting page info data for: Lanett, Alabama
# Getting page info data for: Langston, Alabama
# Getting page info data for: Leeds, Alabama
# Getting page info data for: Leesburg, Alabama
# Getting page info data for: Leighton, Alabama
# Getting page info data for: Lester, Alabama
# Getting page info data for: Level Plains, Alabama
# Getting page info data for: Lexington, Alabama
# Getting page info data for: Libertyville, Alabama
# Getting page info data for: Lincoln, Alabama
# Getting page info data for: Linden, Alabama
# Getting page info data for: Lineville, Alabama
# Getting page info data for: Lipscomb, Alabama
# Getting page info data for: Lisman, Alabama
# Getting page info data for: Littleville, Alabama
# Getting page info data for: Livingston, Alabama
# Getting page info data for: Loachapoka, Alabama
# Getting page info data for: Lockhart, Alabama
# Getting page info data for: Locust Fork, Alabama
# Getting page info data for: Louisville, Alabama
# Getting page info data for: Lowndesboro, Alabama
# Getting page info data for: Loxley, Alabama
# Getting page info data for: Luverne, Alabama
# Getting page info data for: Lynn, Alabama
# Getting page info data for: Madison, Alabama
# Getting page info data for: Madrid, Alabama
# Getting page info data for: Magnolia Springs, Alabama
# Getting page info data for: Malvern, Alabama
# Getting page info data for: Maplesville, Alabama
# Getting page info data for: Margaret, Alabama
# Getting page info data for: Marion, Alabama
# Getting page info data for: Maytown, Alabama
# Getting page info data for: McIntosh, Alabama
# Getting page info data for: McKenzie, Alabama
# Getting page info data for: McMullen, Alabama
# Getting page info data for: Memphis, Alabama
# Getting page info data for: Mentone, Alabama
# Getting page info data for: Midfield, Alabama
# Getting page info data for: Midland City, Alabama
# Getting page info data for: Midway, Alabama
# Getting page info data for: Millbrook, Alabama
# Getting page info data for: Millport, Alabama
# Getting page info data for: Millry, Alabama
# Getting page info data for: Mobile, Alabama
# Getting page info data for: Monroeville, Alabama
# Getting page info data for: Montevallo, Alabama
# Getting page info data for: Montgomery, Alabama
# Getting page info data for: Moody, Alabama
# Getting page info data for: Mooresville, Alabama
# Getting page info data for: Morris, Alabama
# Getting page info data for: Mosses, Alabama
# Getting page info data for: Moulton, Alabama
# Getting page info data for: Moundville, Alabama
# Getting page info data for: Mount Vernon, Alabama
# Getting page info data for: Mountain Brook, Alabama
# Getting page info data for: Mulga, Alabama
# Getting page info data for: Munford, Alabama
# Getting page info data for: Muscle Shoals, Alabama
# Getting page info data for: Myrtlewood, Alabama
# Getting page info data for: Napier Field, Alabama
# Getting page info data for: Natural Bridge, Alabama
# Getting page info data for: Nauvoo, Alabama
# Getting page info data for: Nectar, Alabama
# Getting page info data for: Needham, Alabama
# Getting page info data for: New Brockton, Alabama
# Getting page info data for: New Hope, Alabama
# Getting page info data for: New Site, Alabama
# Getting page info data for: Newbern, Alabama
# Getting page info data for: Newton, Alabama
# Getting page info data for: Newville, Alabama
# Getting page info data for: North Courtland, Alabama
# Getting page info data for: North Johns, Alabama
# Getting page info data for: Northport, Alabama
# Getting page info data for: Notasulga, Alabama
# Getting page info data for: Oak Grove, Alabama
# Getting page info data for: Oak Hill, Alabama
# Getting page info data for: Oakman, Alabama
# Getting page info data for: Odenville, Alabama
# Getting page info data for: Ohatchee, Alabama
# Getting page info data for: Oneonta, Alabama
# Getting page info data for: Onycha, Alabama
# Getting page info data for: Opelika, Alabama
# Getting page info data for: Opp, Alabama
# Getting page info data for: Orange Beach, Alabama
# Getting page info data for: Orrville, Alabama
# Getting page info data for: Owens Cross Roads, Alabama
# Getting page info data for: Oxford, Alabama
# Getting page info data for: Ozark, Alabama
# Getting page info data for: Paint Rock, Alabama
# Getting page info data for: Parrish, Alabama
# Getting page info data for: Pelham, Alabama
# Getting page info data for: Pell City, Alabama
# Getting page info data for: Pennington, Alabama
# Getting page info data for: Perdido Beach, Alabama
# Getting page info data for: Petrey, Alabama
# Getting page info data for: Phenix City, Alabama
# Getting page info data for: Phil Campbell, Alabama
# Getting page info data for: Pickensville, Alabama
# Getting page info data for: Piedmont, Alabama
# Getting page info data for: Pike Road, Alabama
# Getting page info data for: Pinckard, Alabama
# Getting page info data for: Pine Apple, Alabama
# Getting page info data for: Pine Hill, Alabama
# Getting page info data for: Pine Ridge, Alabama
# Getting page info data for: Pinson, Alabama
# Getting page info data for: Pisgah, Alabama
# Getting page info data for: Pleasant Grove, Alabama
# Getting page info data for: Pleasant Groves, Alabama
# Getting page info data for: Pollard, Alabama
# Getting page info data for: Powell, Alabama
# Getting page info data for: Prattville, Alabama
# Getting page info data for: Priceville, Alabama
# Getting page info data for: Prichard, Alabama
# Getting page info data for: Providence, Alabama
# Getting page info data for: Ragland, Alabama
# Getting page info data for: Rainbow City, Alabama
# Getting page info data for: Rainsville, Alabama
# Getting page info data for: Ranburne, Alabama
# Getting page info data for: Red Bay, Alabama
# Getting page info data for: Red Level, Alabama
# Getting page info data for: Reece City, Alabama
# Getting page info data for: Reform, Alabama
# Getting page info data for: Rehobeth, Alabama
# Getting page info data for: Repton, Alabama
# Getting page info data for: Ridgeville, Alabama
# Getting page info data for: River Falls, Alabama
# Getting page info data for: Riverside, Alabama
# Getting page info data for: Riverview, Alabama
# Getting page info data for: Roanoke, Alabama
# Getting page info data for: Robertsdale, Alabama
# Getting page info data for: Rockford, Alabama
# Getting page info data for: Rogersville, Alabama
# Getting page info data for: Rosa, Alabama
# Getting page info data for: Russellville, Alabama
# Getting page info data for: Rutledge, Alabama
# Getting page info data for: St. Florian, Alabama
# Getting page info data for: Samson, Alabama
# Getting page info data for: Sand Rock, Alabama
# Getting page info data for: Sanford, Alabama
# Getting page info data for: Saraland, Alabama
# Getting page info data for: Sardis City, Alabama
# Getting page info data for: Satsuma, Alabama
# Getting page info data for: Scottsboro, Alabama
# Getting page info data for: Section, Alabama
# Getting page info data for: Selma, Alabama
# Getting page info data for: Sheffield, Alabama
# Getting page info data for: Shiloh, DeKalb County, Alabama
# Getting page info data for: Shorter, Alabama
# Getting page info data for: Silas, Alabama
# Getting page info data for: Silverhill, Alabama
# Getting page info data for: Sipsey, Alabama
# Getting page info data for: Skyline, Alabama
# Getting page info data for: Slocomb, Alabama
# Getting page info data for: Smiths Station, Alabama
# Getting page info data for: Snead, Alabama
# Getting page info data for: Somerville, Alabama
# Getting page info data for: South Vinemont, Alabama
# Getting page info data for: Southside, Alabama
# Getting page info data for: Spanish Fort, Alabama
# Getting page info data for: Springville, Alabama
# Getting page info data for: Steele, Alabama
# Getting page info data for: Stevenson, Alabama
# Getting page info data for: Sulligent, Alabama
# Getting page info data for: Sumiton, Alabama
# Getting page info data for: Summerdale, Alabama
# Getting page info data for: Susan Moore, Alabama
# Getting page info data for: Sweet Water, Alabama
# Getting page info data for: Sylacauga, Alabama
# Getting page info data for: Sylvan Springs, Alabama
# Getting page info data for: Sylvania, Alabama
# Getting page info data for: Talladega Springs, Alabama
# Getting page info data for: Talladega, Alabama
# Getting page info data for: Tallassee, Alabama
# Getting page info data for: Tarrant, Alabama
# Getting page info data for: Taylor, Alabama
# Getting page info data for: Thomaston, Alabama
# Getting page info data for: Thomasville, Alabama
# Getting page info data for: Thorsby, Alabama
# Getting page info data for: Town Creek, Alabama
# Getting page info data for: Toxey, Alabama
# Getting page info data for: Trafford, Alabama
# Getting page info data for: Triana, Alabama
# Getting page info data for: Trinity, Alabama
# Getting page info data for: Troy, Alabama
# Getting page info data for: Trussville, Alabama
# Getting page info data for: Tuscaloosa, Alabama
# Getting page info data for: Tuscumbia, Alabama
# Getting page info data for: Tuskegee, Alabama
# Getting page info data for: Twin, Alabama
# Getting page info data for: Union Grove, Alabama
# Getting page info data for: Union Springs, Alabama
# Getting page info data for: Union, Alabama
# Getting page info data for: Uniontown, Alabama
# Getting page info data for: Valley, Alabama
# Getting page info data for: Valley Grande, Alabama
# Getting page info data for: Valley Head, Alabama
# Getting page info data for: Vance, Alabama
# Getting page info data for: Vernon, Alabama
# Getting page info data for: Vestavia Hills, Alabama
# Getting page info data for: Vina, Alabama
# Getting page info data for: Vincent, Alabama
# Getting page info data for: Vredenburgh, Alabama
# Getting page info data for: Wadley, Alabama
# Getting page info data for: Waldo, Alabama
# Getting page info data for: Walnut Grove, Alabama
# Getting page info data for: Warrior, Alabama
# Getting page info data for: Waterloo, Alabama
# Getting page info data for: Waverly, Alabama
# Getting page info data for: Weaver, Alabama
# Getting page info data for: Webb, Alabama
# Getting page info data for: Wedowee, Alabama
# Getting page info data for: West Blocton, Alabama
# Getting page info data for: West Jefferson, Alabama
# Getting page info data for: West Point, Alabama
# Getting page info data for: Westover, Alabama
# Getting page info data for: Wetumpka, Alabama
# Getting page info data for: White Hall, Alabama
# Getting page info data for: Wilsonville, Alabama
# Getting page info data for: Wilton, Alabama
# Getting page info data for: Winfield, Alabama
# Getting page info data for: Woodland, Alabama
# Getting page info data for: Woodstock, Alabama
# Getting page info data for: Woodville, Alabama
# Getting page info data for: Yellow Bluff, Alabama
# Getting page info data for: York, Alabama
# Getting page info data for: Abbeville, Alabama
# Getting page info data for: Adamsville, Alabama
# Getting page info data for: Addison, Alabama
# Getting page info data for: Akron, Alabama
# Getting page info data for: Alabaster, Alabama
# Getting page info data for: Albertville, Alabama
# Getting page info data for: Alexander City, Alabama
# Getting page info data for: Aliceville, Alabama
# Getting page info data for: Allgood, Alabama
# Getting page info data for: Altoona, Alabama
# Getting page info data for: Andalusia, Alabama
# Getting page info data for: Anderson, Lauderdale County, Alabama
# Getting page info data for: Anniston, Alabama
# Getting page info data for: Arab, Alabama
# Getting page info data for: Ardmore, Alabama
# Getting page info data for: Argo, Alabama
# Getting page info data for: Ariton, Alabama
# Getting page info data for: Arley, Alabama
# Getting page info data for: Ashford, Alabama
# Getting page info data for: Ashland, Alabama
# Getting page info data for: Ashville, Alabama
# Getting page info data for: Athens, Alabama
# Getting page info data for: Atmore, Alabama
# Getting page info data for: Attalla, Alabama
# Getting page info data for: Auburn, Alabama
# Getting page info data for: Autaugaville, Alabama
# Getting page info data for: Avon, Alabama
# Getting page info data for: Babbie, Alabama
# Getting page info data for: Baileyton, Alabama
# Getting page info data for: Bakerhill, Alabama
# Getting page info data for: Banks, Alabama
# Getting page info data for: Bay Minette, Alabama
# Getting page info data for: Bayou La Batre, Alabama
# Getting page info data for: Bear Creek, Alabama
# Getting page info data for: Beatrice, Alabama
# Getting page info data for: Beaverton, Alabama
# Getting page info data for: Belk, Alabama
# Getting page info data for: Benton, Alabama
# Getting page info data for: Berlin, Alabama
# Getting page info data for: Berry, Alabama
# Getting page info data for: Bessemer, Alabama
# Getting page info data for: Billingsley, Alabama
# Getting page info data for: Birmingham, Alabama
# Getting page info data for: Black, Alabama
# Getting page info data for: Blountsville, Alabama
# Getting page info data for: Blue Springs, Alabama
# Getting page info data for: Boaz, Alabama
# Getting page info data for: Boligee, Alabama
# Getting page info data for: Bon Air, Alabama
# Getting page info data for: Brantley, Alabama
# Getting page info data for: Brent, Alabama
# Getting page info data for: Brewton, Alabama
# Getting page info data for: Bridgeport, Alabama
# Getting page info data for: Brighton, Alabama
# Getting page info data for: Brilliant, Alabama
# Getting page info data for: Brookside, Alabama
# Getting page info data for: Brookwood, Alabama
# Getting page info data for: Brundidge, Alabama
# Getting page info data for: Butler, Alabama
# Getting page info data for: Calera, Alabama
# Getting page info data for: Camden, Alabama
# Getting page info data for: Camp Hill, Alabama
# Getting page info data for: Carbon Hill, Alabama
# Getting page info data for: Cardiff, Alabama
# Getting page info data for: Carolina, Alabama
# Getting page info data for: Carrollton, Alabama
# Getting page info data for: Castleberry, Alabama
# Getting page info data for: Cedar Bluff, Alabama
# Getting page info data for: Center Point, Alabama
# Getting page info data for: Centre, Alabama
# Getting page info data for: Centreville, Alabama
# Getting page info data for: Chatom, Alabama
# Getting page info data for: Chelsea, Alabama
# Getting page info data for: Cherokee, Alabama
# Getting page info data for: Chickasaw, Alabama
# Getting page info data for: Childersburg, Alabama
# Getting page info data for: Citronelle, Alabama
# Getting page info data for: Clanton, Alabama
# Getting page info data for: Clay, Alabama
# Getting page info data for: Clayhatchee, Alabama
# Getting page info data for: Clayton, Alabama
# Getting page info data for: Cleveland, Alabama
# Getting page info data for: Clio, Alabama
# Getting page info data for: Coaling, Alabama
# Getting page info data for: Coffee Springs, Alabama
# Getting page info data for: Coffeeville, Alabama
# Getting page info data for: Coker, Alabama
# Getting page info data for: Collinsville, Alabama
# Getting page info data for: Colony, Alabama
# Getting page info data for: Columbia, Alabama
# Getting page info data for: Columbiana, Alabama
# Getting page info data for: Coosada, Alabama
# Getting page info data for: Cordova, Alabama
# Getting page info data for: Cottonwood, Alabama
# Getting page info data for: County Line, Alabama
# Getting page info data for: Courtland, Alabama
# Getting page info data for: Cowarts, Alabama
# Getting page info data for: Creola, Alabama
# Getting page info data for: Crossville, Alabama
# Getting page info data for: Cuba, Alabama
# Getting page info data for: Cullman, Alabama
# Getting page info data for: Cusseta, Alabama
# Getting page info data for: Dadeville, Alabama
# Getting page info data for: Daleville, Alabama
# Getting page info data for: Daphne, Alabama
# Getting page info data for: Dauphin Island, Alabama
# Getting page info data for: Daviston, Alabama
# Getting page info data for: Dayton, Alabama
# Getting page info data for: Deatsville, Alabama
# Getting page info data for: Decatur, Alabama
# Getting page info data for: Demopolis, Alabama
# Getting page info data for: Detroit, Alabama
# Getting page info data for: Dodge City, Alabama
# Getting page info data for: Dora, Alabama
# Getting page info data for: Dothan, Alabama
# Getting page info data for: Double Springs, Alabama
# Getting page info data for: Douglas, Alabama
# Getting page info data for: Dozier, Alabama
# Getting page info data for: Dutton, Alabama
# Getting page info data for: East Brewton, Alabama
# Getting page info data for: Eclectic, Alabama
# Getting page info data for: Edwardsville, Alabama
# Getting page info data for: Elba, Alabama
# Getting page info data for: Elberta, Alabama
# Getting page info data for: Eldridge, Alabama
# Getting page info data for: Elkmont, Alabama
# Getting page info data for: Elmore, Alabama
# Getting page info data for: Emelle, Alabama
# Getting page info data for: Enterprise, Alabama
# Getting page info data for: Epes, Alabama
# Getting page info data for: Ethelsville, Alabama
# Getting page info data for: Eufaula, Alabama
# Getting page info data for: Eutaw, Alabama
# Getting page info data for: Eva, Alabama
# Getting page info data for: Evergreen, Conecuh County, Alabama
# Getting page info data for: Excel, Alabama
# Getting page info data for: Fairfield, Alabama
# Getting page info data for: Fairhope, Alabama
# Getting page info data for: Fairview, Alabama
# Getting page info data for: Falkville, Alabama
# Getting page info data for: Faunsdale, Alabama
# Getting page info data for: Fayette, Alabama
# Getting page info data for: Five Points, Alabama
# Getting page info data for: Flomaton, Alabama
# Getting page info data for: Florala, Alabama
# Getting page info data for: Florence, Alabama
# Getting page info data for: Foley, Alabama
# Getting page info data for: Forkland, Alabama
# Getting page info data for: Fort Deposit, Alabama
# Getting page info data for: Fort Payne, Alabama
# Getting page info data for: Franklin, Alabama
# Getting page info data for: Frisco City, Alabama
# Getting page info data for: Fruithurst, Alabama
# Getting page info data for: Fulton, Alabama
# Getting page info data for: Fultondale, Alabama
# Getting page info data for: Fyffe, Alabama
# Getting page info data for: Gadsden, Alabama
# Getting page info data for: Gainesville, Alabama
# Getting page info data for: Gantt, Alabama
# Getting page info data for: Garden City, Alabama
# Getting page info data for: Gardendale, Alabama
# Getting page info data for: Gaylesville, Alabama
# Getting page info data for: Geiger, Alabama
# Getting page info data for: Geneva, Alabama
# Getting page info data for: Georgiana, Alabama
# Getting page info data for: Geraldine, Alabama
# Getting page info data for: Gilbertown, Alabama
# Getting page info data for: Glen Allen, Alabama
# Getting page info data for: Glencoe, Alabama
# Getting page info data for: Glenwood, Alabama
# Getting page info data for: Goldville, Alabama
# Getting page info data for: Good Hope, Alabama
# Getting page info data for: Goodwater, Alabama
# Getting page info data for: Gordo, Alabama
# Getting page info data for: Gordon, Alabama
# Getting page info data for: Gordonville, Alabama
# Getting page info data for: Goshen, Alabama
# Getting page info data for: Grant, Alabama
# Getting page info data for: Graysville, Alabama
# Getting page info data for: Greensboro, Alabama
# Getting page info data for: Greenville, Alabama
# Getting page info data for: Grimes, Alabama
# Getting page info data for: Grove Hill, Alabama
# Getting page info data for: Guin, Alabama
# Getting page info data for: Gulf Shores, Alabama
# Getting page info data for: Guntersville, Alabama
# Getting page info data for: Gurley, Alabama
# Getting page info data for: Gu-Win, Alabama
# Getting page info data for: Hackleburg, Alabama
# Getting page info data for: Haleburg, Alabama
# Getting page info data for: Haleyville, Alabama
# Getting page info data for: Hamilton, Alabama
# Getting page info data for: Hammondville, Alabama
# Getting page info data for: Hanceville, Alabama
# Getting page info data for: Harpersville, Alabama
# Getting page info data for: Hartford, Alabama
# Getting page info data for: Hartselle, Alabama
# Getting page info data for: Hayden, Alabama
# Getting page info data for: Hayneville, Alabama
# Getting page info data for: Headland, Alabama
# Getting page info data for: Heath, Alabama
# Getting page info data for: Heflin, Alabama
# Getting page info data for: Helena, Alabama
# Getting page info data for: Henagar, Alabama
# Getting page info data for: Highland Lake, Alabama
# Getting page info data for: Hillsboro, Alabama
# Getting page info data for: Hobson City, Alabama
# Getting page info data for: Hodges, Alabama
# Getting page info data for: Hokes Bluff, Alabama
# Getting page info data for: Holly Pond, Alabama
# Getting page info data for: Hollywood, Alabama
# Getting page info data for: Homewood, Alabama
# Getting page info data for: Hoover, Alabama
# Getting page info data for: Horn Hill, Alabama
# Getting page info data for: Hueytown, Alabama
# Getting page info data for: Huntsville, Alabama
# Getting page info data for: Hurtsboro, Alabama
# Getting page info data for: Hytop, Alabama
# Getting page info data for: Ider, Alabama
# Getting page info data for: Indian Springs Village, Alabama
# Getting page info data for: Irondale, Alabama
# Getting page info data for: Jackson, Alabama
# Getting page info data for: Jackson's Gap, Alabama
# Getting page info data for: Jacksonville, Alabama
# Getting page info data for: Jasper, Alabama
# Getting page info data for: Jemison, Alabama
# Getting page info data for: Kansas, Alabama
# Getting page info data for: Kellyton, Alabama
# Getting page info data for: Kennedy, Alabama
# Getting page info data for: Killen, Alabama
# Getting page info data for: Kimberly, Alabama
# Getting page info data for: Kinsey, Alabama
# Getting page info data for: Kinston, Alabama
# Getting page info data for: LaFayette, Alabama
# Getting page info data for: Lake View, Alabama
# Getting page info data for: Lakeview, Alabama
# Getting page info data for: Lanett, Alabama
# Getting page info data for: Langston, Alabama
# Getting page info data for: Leeds, Alabama
# Getting page info data for: Leesburg, Alabama
# Getting page info data for: Leighton, Alabama
# Getting page info data for: Lester, Alabama
# Getting page info data for: Level Plains, Alabama
# Getting page info data for: Lexington, Alabama
# Getting page info data for: Libertyville, Alabama
# Getting page info data for: Lincoln, Alabama
# Getting page info data for: Linden, Alabama
# Getting page info data for: Lineville, Alabama
# Getting page info data for: Lipscomb, Alabama
# Getting page info data for: Lisman, Alabama
# Getting page info data for: Littleville, Alabama
# Getting page info data for: Livingston, Alabama
# Getting page info data for: Loachapoka, Alabama
# Getting page info data for: Lockhart, Alabama
# Getting page info data for: Locust Fork, Alabama
# Getting page info data for: Louisville, Alabama
# Getting page info data for: Lowndesboro, Alabama
# Getting page info data for: Loxley, Alabama
# Getting page info data for: Luverne, Alabama
# Getting page info data for: Lynn, Alabama
# Getting page info data for: Madison, Alabama
# Getting page info data for: Madrid, Alabama
# Getting page info data for: Magnolia Springs, Alabama
# Getting page info data for: Malvern, Alabama
# Getting page info data for: Maplesville, Alabama
# Getting page info data for: Margaret, Alabama
# Getting page info data for: Marion, Alabama
# Getting page info data for: Maytown, Alabama
# Getting page info data for: McIntosh, Alabama
# Getting page info data for: McKenzie, Alabama
# Getting page info data for: McMullen, Alabama
# Getting page info data for: Memphis, Alabama
# Getting page info data for: Mentone, Alabama
# Getting page info data for: Midfield, Alabama
# Getting page info data for: Midland City, Alabama
# Getting page info data for: Midway, Alabama
# Getting page info data for: Millbrook, Alabama
# Getting page info data for: Millport, Alabama
# Getting page info data for: Millry, Alabama
# Getting page info data for: Mobile, Alabama
# Getting page info data for: Monroeville, Alabama
# Getting page info data for: Montevallo, Alabama
# Getting page info data for: Montgomery, Alabama
# Getting page info data for: Moody, Alabama
# Getting page info data for: Mooresville, Alabama
# Getting page info data for: Morris, Alabama
# Getting page info data for: Mosses, Alabama
# Getting page info data for: Moulton, Alabama
# Getting page info data for: Moundville, Alabama
# Getting page info data for: Mount Vernon, Alabama
# Getting page info data for: Mountain Brook, Alabama
# Getting page info data for: Mulga, Alabama
# Getting page info data for: Munford, Alabama
# Getting page info data for: Muscle Shoals, Alabama
# Getting page info data for: Myrtlewood, Alabama
# Getting page info data for: Napier Field, Alabama
# Getting page info data for: Natural Bridge, Alabama
# Getting page info data for: Nauvoo, Alabama
# Getting page info data for: Nectar, Alabama
# Getting page info data for: Needham, Alabama
# Getting page info data for: New Brockton, Alabama
# Getting page info data for: New Hope, Alabama
# Getting page info data for: New Site, Alabama
# Getting page info data for: Newbern, Alabama
# Getting page info data for: Newton, Alabama
# Getting page info data for: Newville, Alabama
# Getting page info data for: North Courtland, Alabama
# Getting page info data for: North Johns, Alabama
# Getting page info data for: Northport, Alabama
# Getting page info data for: Notasulga, Alabama
# Getting page info data for: Oak Grove, Alabama
# Getting page info data for: Oak Hill, Alabama
# Getting page info data for: Oakman, Alabama
# Getting page info data for: Odenville, Alabama
# Getting page info data for: Ohatchee, Alabama
# Getting page info data for: Oneonta, Alabama
# Getting page info data for: Onycha, Alabama
# Getting page info data for: Opelika, Alabama
# Getting page info data for: Opp, Alabama
# Getting page info data for: Orange Beach, Alabama
# Getting page info data for: Orrville, Alabama
# Getting page info data for: Owens Cross Roads, Alabama
# Getting page info data for: Oxford, Alabama
# Getting page info data for: Ozark, Alabama
# Getting page info data for: Paint Rock, Alabama
# Getting page info data for: Parrish, Alabama
# Getting page info data for: Pelham, Alabama
# Getting page info data for: Pell City, Alabama
# Getting page info data for: Pennington, Alabama
# Getting page info data for: Perdido Beach, Alabama
# Getting page info data for: Petrey, Alabama
# Getting page info data for: Phenix City, Alabama
# Getting page info data for: Phil Campbell, Alabama
# Getting page info data for: Pickensville, Alabama
# Getting page info data for: Piedmont, Alabama
# Getting page info data for: Pike Road, Alabama
# Getting page info data for: Pinckard, Alabama
# Getting page info data for: Pine Apple, Alabama
# Getting page info data for: Pine Hill, Alabama
# Getting page info data for: Pine Ridge, Alabama
# Getting page info data for: Pinson, Alabama
# Getting page info data for: Pisgah, Alabama
# Getting page info data for: Pleasant Grove, Alabama
# Getting page info data for: Pleasant Groves, Alabama
# Getting page info data for: Pollard, Alabama
# Getting page info data for: Powell, Alabama
# Getting page info data for: Prattville, Alabama
# Getting page info data for: Priceville, Alabama
# Getting page info data for: Prichard, Alabama
# Getting page info data for: Providence, Alabama
# Getting page info data for: Ragland, Alabama
# Getting page info data for: Rainbow City, Alabama
# Getting page info data for: Rainsville, Alabama
# Getting page info data for: Ranburne, Alabama
# Getting page info data for: Red Bay, Alabama
# Getting page info data for: Red Level, Alabama
# Getting page info data for: Reece City, Alabama
# Getting page info data for: Reform, Alabama
# Getting page info data for: Rehobeth, Alabama
# Getting page info data for: Repton, Alabama
# Getting page info data for: Ridgeville, Alabama
# Getting page info data for: River Falls, Alabama
# Getting page info data for: Riverside, Alabama
# Getting page info data for: Riverview, Alabama
# Getting page info data for: Roanoke, Alabama
# Getting page info data for: Robertsdale, Alabama
# Getting page info data for: Rockford, Alabama
# Getting page info data for: Rogersville, Alabama
# Getting page info data for: Rosa, Alabama
# Getting page info data for: Russellville, Alabama
# Getting page info data for: Rutledge, Alabama
# Getting page info data for: St. Florian, Alabama
# Getting page info data for: Samson, Alabama
# Getting page info data for: Sand Rock, Alabama
# Getting page info data for: Sanford, Alabama
# Getting page info data for: Saraland, Alabama
# Getting page info data for: Sardis City, Alabama
# Getting page info data for: Satsuma, Alabama
# Getting page info data for: Scottsboro, Alabama
# Getting page info data for: Section, Alabama
# Getting page info data for: Selma, Alabama
# Getting page info data for: Sheffield, Alabama
# Getting page info data for: Shiloh, DeKalb County, Alabama
# Getting page info data for: Shorter, Alabama
# Getting page info data for: Silas, Alabama
# Getting page info data for: Silverhill, Alabama
# Getting page info data for: Sipsey, Alabama
# Getting page info data for: Skyline, Alabama
# Getting page info data for: Slocomb, Alabama
# Getting page info data for: Smiths Station, Alabama
# Getting page info data for: Snead, Alabama
# Getting page info data for: Somerville, Alabama
# Getting page info data for: South Vinemont, Alabama
# Getting page info data for: Southside, Alabama
# Getting page info data for: Spanish Fort, Alabama
# Getting page info data for: Springville, Alabama
# Getting page info data for: Steele, Alabama
# Getting page info data for: Stevenson, Alabama
# Getting page info data for: Sulligent, Alabama
# Getting page info data for: Sumiton, Alabama
# Getting page info data for: Summerdale, Alabama
# Getting page info data for: Susan Moore, Alabama
# Getting page info data for: Sweet Water, Alabama
# Getting page info data for: Sylacauga, Alabama
# Getting page info data for: Sylvan Springs, Alabama
# Getting page info data for: Sylvania, Alabama
# Getting page info data for: Talladega Springs, Alabama
# Getting page info data for: Talladega, Alabama
# Getting page info data for: Tallassee, Alabama
# Getting page info data for: Tarrant, Alabama
# Getting page info data for: Taylor, Alabama
# Getting page info data for: Thomaston, Alabama
# Getting page info data for: Thomasville, Alabama
# Getting page info data for: Thorsby, Alabama
# Getting page info data for: Town Creek, Alabama
# Getting page info data for: Toxey, Alabama
# Getting page info data for: Trafford, Alabama
# Getting page info data for: Triana, Alabama
# Getting page info data for: Trinity, Alabama
# Getting page info data for: Troy, Alabama
# Getting page info data for: Trussville, Alabama
# Getting page info data for: Tuscaloosa, Alabama
# Getting page info data for: Tuscumbia, Alabama
# Getting page info data for: Tuskegee, Alabama
# Getting page info data for: Twin, Alabama
# Getting page info data for: Union Grove, Alabama
# Getting page info data for: Union Springs, Alabama
# Getting page info data for: Union, Alabama
# Getting page info data for: Uniontown, Alabama
# Getting page info data for: Valley, Alabama
# Getting page info data for: Valley Grande, Alabama
# Getting page info data for: Valley Head, Alabama
# Getting page info data for: Vance, Alabama
# Getting page info data for: Vernon, Alabama
# Getting page info data for: Vestavia Hills, Alabama
# Getting page info data for: Vina, Alabama
# Getting page info data for: Vincent, Alabama
# Getting page info data for: Vredenburgh, Alabama
# Getting page info data for: Wadley, Alabama
# Getting page info data for: Waldo, Alabama
# Getting page info data for: Walnut Grove, Alabama
# Getting page info data for: Warrior, Alabama
# Getting page info data for: Waterloo, Alabama
# Getting page info data for: Waverly, Alabama
# Getting page info data for: Weaver, Alabama
# Getting page info data for: Webb, Alabama
# Getting page info data for: Wedowee, Alabama
# Getting page info data for: West Blocton, Alabama
# Getting page info data for: West Jefferson, Alabama
# Getting page info data for: West Point, Alabama
# Getting page info data for: Westover, Alabama
# Getting page info data for: Wetumpka, Alabama
# Getting page info data for: White Hall, Alabama
# Getting page info data for: Wilsonville, Alabama
# Getting page info data for: Wilton, Alabama
# Getting page info data for: Winfield, Alabama
# Getting page info data for: Woodland, Alabama
# Getting page info data for: Woodstock, Alabama
# Getting page info data for: Woodville, Alabama
# Getting page info data for: Yellow Bluff, Alabama
# Getting page info data for: York, Alabama
# Getting page info data for: Adak, Alaska
# Getting page info data for: Akhiok, Alaska
# Getting page info data for: Akiak, Alaska
# Getting page info data for: Akutan, Alaska
# Getting page info data for: Alakanuk, Alaska
# Getting page info data for: Aleknagik, Alaska
# Getting page info data for: Allakaket, Alaska
# Getting page info data for: Ambler, Alaska
# Getting page info data for: Anaktuvuk Pass, Alaska
# Getting page info data for: Anchorage, Alaska
# Getting page info data for: Anderson, Alaska
# Getting page info data for: Angoon, Alaska
# Getting page info data for: Aniak, Alaska
# Getting page info data for: Anvik, Alaska
# Getting page info data for: Atka, Alaska
# Getting page info data for: Atqasuk, Alaska
# Getting page info data for: Bethel, Alaska
# Getting page info data for: Bettles, Alaska
# Getting page info data for: Brevig Mission, Alaska
# Getting page info data for: Buckland, Alaska
# Getting page info data for: Chefornak, Alaska
# Getting page info data for: Chevak, Alaska
# Getting page info data for: Chignik, Alaska
# Getting page info data for: Chuathbaluk, Alaska
# Getting page info data for: Clark's Point, Alaska
# Getting page info data for: Coffman Cove, Alaska
# Getting page info data for: Cold Bay, Alaska
# Getting page info data for: Cordova, Alaska
# Getting page info data for: Craig, Alaska
# Getting page info data for: Deering, Alaska
# Getting page info data for: Delta Junction, Alaska
# Getting page info data for: Dillingham, Alaska
# Getting page info data for: Diomede, Alaska
# Getting page info data for: Eagle, Alaska
# Getting page info data for: Edna Bay, Alaska
# Getting page info data for: Eek, Alaska
# Getting page info data for: Egegik, Alaska
# Getting page info data for: Ekwok, Alaska
# Getting page info data for: Elim, Alaska
# Getting page info data for: Emmonak, Alaska
# Getting page info data for: Fairbanks, Alaska
# Getting page info data for: False Pass, Alaska
# Getting page info data for: Fort Yukon, Alaska
# Getting page info data for: Galena, Alaska
# Getting page info data for: Gambell, Alaska
# Getting page info data for: Golovin, Alaska
# Getting page info data for: Goodnews Bay, Alaska
# Getting page info data for: Grayling, Alaska
# Getting page info data for: Gustavus, Alaska
# Getting page info data for: Holy Cross, Alaska
# Getting page info data for: Homer, Alaska
# Getting page info data for: Hoonah, Alaska
# Getting page info data for: Hooper Bay, Alaska
# Getting page info data for: Houston, Alaska
# Getting page info data for: Hughes, Alaska
# Getting page info data for: Huslia, Alaska
# Getting page info data for: Hydaburg, Alaska
# Getting page info data for: Juneau, Alaska
# Getting page info data for: Kachemak, Alaska
# Getting page info data for: Kake, Alaska
# Getting page info data for: Kaktovik, Alaska
# Getting page info data for: Kaltag, Alaska
# Getting page info data for: Kasaan, Alaska
# Getting page info data for: Kenai, Alaska
# Getting page info data for: Ketchikan, Alaska
# Getting page info data for: Kiana, Alaska
# Getting page info data for: King Cove, Alaska
# Getting page info data for: Kivalina, Alaska
# Getting page info data for: Klawock, Alaska
# Getting page info data for: Kobuk, Alaska
# Getting page info data for: Kodiak, Alaska
# Getting page info data for: Kotlik, Alaska
# Getting page info data for: Kotzebue, Alaska
# Getting page info data for: Koyuk, Alaska
# Getting page info data for: Koyukuk, Alaska
# Getting page info data for: Kupreanof, Alaska
# Getting page info data for: Kwethluk, Alaska
# Getting page info data for: Larsen Bay, Alaska

# %% [markdown]
# As the API takes a very long time to fetch all the data, we will write the list of dicts to an offline file in json format

# %%
city_data = open('/content/drive/MyDrive/city.json', "w")
json.dump(article_info_list, city_data, indent = 4)
city_data.close()

# %%
#Reading the city json
file_path_city = '/content/drive/My Drive/city.json'
with open(file_path_city, 'r') as json_file:
  article_info_list = json.load(json_file)

# %% [markdown]
# The next step would be to extract the useful information from the list of dicts we have created. Out of this, we need the title of the article and the lastrevid. We extract this data and append it to a new list.

# %%
title_revid_list = [{'title': item['title'], 'lastrevid': item['lastrevid']} for item in article_info_list]

# %% [markdown]
# ## The ORES API

# %% [markdown]
# After we have the data, we will hit another API which will give us the ORES rating of the articles we have in our list. he machine learning system used for this purpose is called [ORES](https://www.mediawiki.org/wiki/ORES). This was originally an acronym for 'Objective Revision Evaluation Service' but was simply renamed 'ORES'. ORES is a machine learning tool that can provide estimates of Wikipedia article quality. The article quality estimates are labelings learned based on articles in Wikipedia that were peer-reviewed using the [Wikipedia content assessment](https://en.wikipedia.org/wiki/Wikipedia:Content_assessment) procedures. These quality classes are a subset of quality assessment categories developed by Wikipedia editors, ranked below from best to worst:
#
# 1. FA - Featured article
# 2. GA - Good article (sometimes called A-class)
# 3. B - B-class article
# 4. C - C-class article
# 5. Start - Start-class article
# 6. Stub - Stub-class article
#
# ORES requires a specific revision ID of a specific article to be able to make a label prediction. You can use the [API:Info](https://www.mediawiki.org/wiki/API:Info) request to get a range of metadata on an article, including the most current revision ID of the article page. For more information, the [ORES API documentation](https://ores.wikimedia.org/) can be accessed from the main ORES page.

# %% [markdown]
# Wikimedia is implementing a new Machine Learning (ML) service infrastructure that they call [LiftWing](https://wikitech.wikimedia.org/wiki/Machine_Learning/LiftWing). Given that ORES already has several ML models that have been well used, ORES is the first set of APIs that are being moved to LiftWing. This code below illustrates how to generate article quality estimates for article revisions using the LiftWing version of ORES. The [ORES LiftWing documentation](https://wikitech.wikimedia.org/wiki/Machine_Learning/LiftWing/Usage) has information about some parameters that have been renamed (e.g., "revid" in the old ORES API is now "rev_id" in the LiftWing ORES API).
#
# The code to request ORES scores through LiftWing ML Service API has been sampled from [this notebook](https://drive.google.com/file/d/17C9xsmR9U3lJeD52UTbAedlHDetwYsxs/view?usp=sharing) under the [CC-BY license](https://creativecommons.org/licenses/by/4.0/).

# %%
#    CONSTANTS
#    The current LiftWing ORES API endpoint and prediction model
#
API_ORES_LIFTWING_ENDPOINT = "https://api.wikimedia.org/service/lw/inference/v1/models/{model_name}:predict"
API_ORES_EN_QUALITY_MODEL = "enwiki-articlequality"

#
#    The throttling rate is a function of the Access token that you are granted when you request the token. The constants
#    come from dissecting the token and getting the rate limits from the granted token. An example of that is below.
#
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (60.0/5000.0)-API_LATENCY_ASSUMED

#    When making automated requests we should include something that is unique to the person making the request
#    This should include an email - your UW email would be good to put in there

#    Because all LiftWing API requests require some form of authentication, you need to provide your access token
#    as part of the header too

REQUEST_HEADER_TEMPLATE = {
    'User-Agent': "<gera.vritesh@gmail.com>, University of Washington, MSDS DATA 512 - AUTUMN 2023",
    'Content-Type': 'application/json',
    'Authorization': "Bearer {access_token}"
}

#    This is a template for the parameters that we need to supply in the headers of an API request

REQUEST_HEADER_PARAMS_TEMPLATE = {
    'email_address' : "gera.vritesh@gmail.com",         # your email address should go here
    'access_token'  : "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.....idz7vxuH2RN8vow5X9K_g13KMx3WXykgOXbbb1DNEEWnlgAW0bawraKC3SCsfsJEglQ9CtcUFsAkESx838vAXJ4dIQkOqei5kfBobdCmdfB7w3x77oZWLdXRyjt8xuuMaFBOPPewvKMyzqCBQZTC76EGyYRx_ThM7NQmr_hK-sxVCB97ao3uzUyo2pssQji44gu809c8VnIBHOjXzvf68s2SA6sugd2Yr6Jb363AXZWvykhxQbOBzckkUiTfb0jcVE_MtwuRA_phgJFNK3K50FL6oHa7MJH_Y-gA_ix0Fo116IsTz_lbYXfNVPeHZcHoNYt840UFd2hdxRTNMwyBLkoxgezxCgK_uM5LLlluIpaCephuhBp_jUiCEwck5-DtueZNk-5O3Bwgy_Ju0wRflYFZW4tp_vhdWnpjo-aUj1rLyz4kJPV81TNTf63ymBha2vGp9LREls_QkY3Hy7AF9WXu9wlOAN-_gkmbseQKajY34ASxFBSdVxQ4DnYX_XfoCRe5LRJu428R8Y7yHwnmP6agLvJGDeLt4zrcOx8B_6n9BEA-TbFmBiyf3CUOi5VAUPVWElMKGTfmSHlYAvnjHx_Chec2clzhYNC2Jaxc-8ocUMzICntIy2lCe5FO9AmF0zeCSlUxCtmbiZuCfWu8f3-BhFKbadfhREl0TEm3qwA"          # the access token you create will need to go here
}



# We will input the list of titles along with its revid
ARTICLE_REVISIONS = title_revid_list
#
#    This is a template of the data required as a payload when making a scoring request of the ORES model
#
ORES_REQUEST_DATA_TEMPLATE = {
    "lang":        "en",     # required that its english - we're scoring English Wikipedia revisions
    "rev_id":      "",       # this request requires a revision id
    "features":    True
}

#

#Changed the values to xxx strings because these values shouldn't be distributed openly
USERNAME = "xxx"
ACCESS_TOKEN = "xxxx"
#

# %% [markdown]
# ## Get your Access Token for getting ORES Data

# %% [markdown]
# You will need a Wikimedia user account to get access to Lift Wing (the ML API service). You can either [create an account or login](https://api.wikimedia.org/w/index.php?title=Special:UserLogin). If you have a Wikipedia user account - you might already have an Wikimedia account. If you are not sure try your Wikipedia username and password to check it. If you do not have a Wikimedia account you will need to create an account that you can use to get an access token.
#
# There is [a 'guide' that describes how to get authentication tokens](https://api.wikimedia.org/wiki/Authentication) - but not everything works the way it is described in that documentation. You should review that documentation and then read the rest of this comment.
#
# The documentation talks about using a 'dashboard' for managing authentication tokens. You might have a hard time finding this 'dashboard'. First, on the left hand side of the page, you'll see a column of links. The bottom section is a set of links titled "Tools". In that section is a link that says [Special pages](https://api.wikimedia.org/wiki/Special:SpecialPages). At the very bottom of the 'Special pages' page is a section titled 'Other special pages' (scroll all the way to the bottom). The first link in that section is called [API keys](https://api.wikimedia.org/wiki/Special:AppManagement). When you get to the 'API keys' page you can create a new key.
#
# The authentication guide suggests that you should create a server-side app key which did not work when I tried. But, there is an option to create a [Personal API token](https://api.wikimedia.org/wiki/Authentication) that should work for this study and the type of ORES page scoring that you will need to perform.
#
# Note, when you create a Personal API token you are granted the three items - a Client ID, a Client secret, and a Access token - you shold save all three of these. When you dismiss the box they are gone. If you lose any one of the tokens you can destroy or deactivate the Personal API token from the dashboard and then create a new one.
#
# The value you need to work the code below is the Access token - a very long string.

# %% [markdown]
# ## Define a function to make the ORES API request
#
# The API request will be made using a function to encapsulate call and make access reusable in other notebooks. The procedure is parameterized, relying on the constants above for some important default parameters. The primary assumption is that this function will be used to request data for a set of article revisions. The main parameter is 'article_revid'. One should be able to simply pass in a new article revision id on each call and get back a python dictionary as the result. A valid result will be a dictionary that contains the probabilities that the specific revision is one of six different article quality levels. Generally, quality level with the highest probability score is considered the quality level for the article.

# %%
#    PROCEDURES/FUNCTIONS
def request_ores_score_per_article(article_revid = None, email_address=None, access_token=None,
                                   endpoint_url = API_ORES_LIFTWING_ENDPOINT,
                                   model_name = API_ORES_EN_QUALITY_MODEL,
                                   request_data = ORES_REQUEST_DATA_TEMPLATE,
                                   header_format = REQUEST_HEADER_TEMPLATE,
                                   header_params = REQUEST_HEADER_PARAMS_TEMPLATE):

    #    Make sure we have an article revision id, email and token
    #    This approach prioritizes the parameters passed in when making the call
    if article_revid:
        request_data['rev_id'] = article_revid
    if email_address:
        header_params['email_address'] = email_address
    if access_token:
        header_params['access_token'] = access_token

    #   Making a request requires a revision id - an email address - and the access token
    if not request_data['rev_id']:
        raise Exception("Must provide an article revision id (rev_id) to score articles")
    if not header_params['email_address']:
        raise Exception("Must provide an 'email_address' value")
    if not header_params['access_token']:
        raise Exception("Must provide an 'access_token' value")

    # Create the request URL with the specified model parameter - default is a article quality score request
    request_url = endpoint_url.format(model_name=model_name)

    # Create a compliant request header from the template and the supplied parameters
    headers = dict()
    for key in header_format.keys():
        headers[str(key)] = header_format[key].format(**header_params)

    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free data
        # source like ORES - or other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        #response = requests.get(request_url, headers=headers)
        response = requests.post(request_url, headers=headers, data=json.dumps(request_data))
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %% [markdown]
# Now we will create a list with all the ORES scores based on the revids

# %%
#   Which article - the key for the article dictionary defined above
ores_score_file = []
unscored_article_list = []
for item in ARTICLE_REVISIONS:
  article_title = item['title']
  temp_revind = item['lastrevid']
  print(f"Getting LiftWing ORES scores for '{article_title}' with revid: {temp_revind}")
  score = request_ores_score_per_article(article_revid=temp_revind,
                                       email_address="gera.vritesh@gmail.com",
                                       access_token=ACCESS_TOKEN)
  if score:
    ores_score_file.append(score)
    print(json.dumps(score,indent=4))
  else:
    unscored_article_list
# Out:
# Streaming output truncated to the last 5000 lines.
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Red Bay, Alabama' with revid: 1169333757
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1169333757": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.2808033331369756,
#                             "C": 0.6241599246116336,
#                             "FA": 0.016545542445909205,
#                             "GA": 0.05155356322806621,
#                             "Start": 0.023080365037708828,
#                             "Stub": 0.0038572715397066325
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Red Level, Alabama' with revid: 1166229671
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166229671": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.20671566803259983,
#                             "C": 0.3544672441227104,
#                             "FA": 0.006922021466785656,
#                             "GA": 0.09164822931668146,
#                             "Start": 0.33310914453512114,
#                             "Stub": 0.007137692526101557
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Reece City, Alabama' with revid: 1166229699
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166229699": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "Start",
#                         "probability": {
#                             "B": 0.1385336408760559,
#                             "C": 0.3383173190045638,
#                             "FA": 0.0084156085420001,
#                             "GA": 0.07901448674090347,
#                             "Start": 0.4219541491415108,
#                             "Stub": 0.013764795694965852
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Reform, Alabama' with revid: 1165899409
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165899409": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.18734490133922285,
#                             "C": 0.39427873932998786,
#                             "FA": 0.009593247534970864,
#                             "GA": 0.2403435458475879,
#                             "Start": 0.16327023477599661,
#                             "Stub": 0.00516933117223387
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Rehobeth, Alabama' with revid: 1172196089
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1172196089": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.18899993041536314,
#                             "C": 0.40208117032383095,
#                             "FA": 0.009417707373555333,
#                             "GA": 0.09747114055719375,
#                             "Start": 0.2961980490328212,
#                             "Stub": 0.005832002297235543
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Repton, Alabama' with revid: 1166229759
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166229759": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "Start",
#                         "probability": {
#                             "B": 0.12940935224399452,
#                             "C": 0.29325709869214284,
#                             "FA": 0.006449224767129456,
#                             "GA": 0.0603006555682185,
#                             "Start": 0.4955806074919732,
#                             "Stub": 0.015003061236541491
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Ridgeville, Alabama' with revid: 1166229906
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166229906": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "Start",
#                         "probability": {
#                             "B": 0.20053348159819578,
#                             "C": 0.2637241111788109,
#                             "FA": 0.00713357565007595,
#                             "GA": 0.25134856890416574,
#                             "Start": 0.26937621605264744,
#                             "Stub": 0.00788404661610405
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'River Falls, Alabama' with revid: 1166230019
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166230019": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.18913710709429757,
#                             "C": 0.3610635539866408,
#                             "FA": 0.007300491263490717,
#                             "GA": 0.09767592662257113,
#                             "Start": 0.33576701558303734,
#                             "Stub": 0.009055905449962593
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Riverside, Alabama' with revid: 1166230024
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166230024": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.19079417125915632,
#                             "C": 0.44644285775101367,
#                             "FA": 0.007885816366403115,
#                             "GA": 0.07207067742617537,
#                             "Start": 0.27542562136609483,
#                             "Stub": 0.007380855831156626
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Riverview, Alabama' with revid: 1166230040
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166230040": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "Start",
#                         "probability": {
#                             "B": 0.18098375571222908,
#                             "C": 0.3496939929457784,
#                             "FA": 0.006863291196876274,
#                             "GA": 0.09086898928814147,
#                             "Start": 0.3613100907486778,
#                             "Stub": 0.010279880108297005
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Roanoke, Alabama' with revid: 1165899878
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165899878": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.26650292849859636,
#                             "C": 0.48435860816841403,
#                             "FA": 0.013025255585721584,
#                             "GA": 0.13304690661697868,
#                             "Start": 0.09746165387624874,
#                             "Stub": 0.005604647254040718
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Robertsdale, Alabama' with revid: 1166314424
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166314424": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.1518547719444088,
#                             "C": 0.5762524762787837,
#                             "FA": 0.004659792765763292,
#                             "GA": 0.020132209753031878,
#                             "Start": 0.242782864424036,
#                             "Stub": 0.004317884833976443
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Rockford, Alabama' with revid: 1169199856
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1169199856": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "GA",
#                         "probability": {
#                             "B": 0.19229972558931005,
#                             "C": 0.33948718498842295,
#                             "FA": 0.022177421262294182,
#                             "GA": 0.3717789002846583,
#                             "Start": 0.06984226442514016,
#                             "Stub": 0.004414503450174225
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Rogersville, Alabama' with revid: 1166230187
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166230187": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.2487843882934066,
#                             "C": 0.4248870577144857,
#                             "FA": 0.0094111901730193,
#                             "GA": 0.22393020694392052,
#                             "Start": 0.08789938733190757,
#                             "Stub": 0.005087769543260284
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Rosa, Alabama' with revid: 1166230264
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166230264": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "Start",
#                         "probability": {
#                             "B": 0.20367340393470554,
#                             "C": 0.34861529573153005,
#                             "FA": 0.007484376388194237,
#                             "GA": 0.04901925768268736,
#                             "Start": 0.3796475939183875,
#                             "Stub": 0.011560072344495416
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Russellville, Alabama' with revid: 1165900503
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165900503": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "GA",
#                         "probability": {
#                             "B": 0.17498522206178002,
#                             "C": 0.38280387940440225,
#                             "FA": 0.015968958162199058,
#                             "GA": 0.39673877959409976,
#                             "Start": 0.025415540448189226,
#                             "Stub": 0.004087620329329678
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Rutledge, Alabama' with revid: 1166230534
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166230534": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "Start",
#                         "probability": {
#                             "B": 0.1619588091349609,
#                             "C": 0.2986685003321133,
#                             "FA": 0.006943891766314338,
#                             "GA": 0.08309347374880395,
#                             "Start": 0.4390926670255446,
#                             "Stub": 0.010242657992263142
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'St. Florian, Alabama' with revid: 1166330128
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166330128": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.16542502969613873,
#                             "C": 0.3042061091691079,
#                             "FA": 0.0067982456037995,
#                             "GA": 0.26076718832814105,
#                             "Start": 0.25259178142486394,
#                             "Stub": 0.010211645777948817
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Samson, Alabama' with revid: 1165900688
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165900688": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.1945327406955738,
#                             "C": 0.3894659518801976,
#                             "FA": 0.008604486151090189,
#                             "GA": 0.1301456291960861,
#                             "Start": 0.27182920762850693,
#                             "Stub": 0.005421984448545375
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Sand Rock, Alabama' with revid: 1166230657
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166230657": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.160047948409207,
#                             "C": 0.3433025183032293,
#                             "FA": 0.006636966582349214,
#                             "GA": 0.2715740050812224,
#                             "Start": 0.21281180997295746,
#                             "Stub": 0.005626751651034538
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Sanford, Alabama' with revid: 1166230687
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166230687": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "Start",
#                         "probability": {
#                             "B": 0.13245456477402404,
#                             "C": 0.29137159000340246,
#                             "FA": 0.006816515780591697,
#                             "GA": 0.04939007100765567,
#                             "Start": 0.49954024202886593,
#                             "Stub": 0.020427016405460192
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Saraland, Alabama' with revid: 1176013392
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1176013392": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "GA",
#                         "probability": {
#                             "B": 0.23574034244847164,
#                             "C": 0.2738384623261468,
#                             "FA": 0.023541618359524074,
#                             "GA": 0.44168795905784547,
#                             "Start": 0.021379444589878914,
#                             "Stub": 0.003812173218133135
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Sardis City, Alabama' with revid: 1166230721
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166230721": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.16891054874237518,
#                             "C": 0.354801139106905,
#                             "FA": 0.006297425248120692,
#                             "GA": 0.26109686920228226,
#                             "Start": 0.2043307138985667,
#                             "Stub": 0.004563303801750277
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Satsuma, Alabama' with revid: 1165900914
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165900914": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.25678471130146086,
#                             "C": 0.6451430724725504,
#                             "FA": 0.007421659744854774,
#                             "GA": 0.06207980413403807,
#                             "Start": 0.024923110702566833,
#                             "Stub": 0.0036476416445289893
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Scottsboro, Alabama' with revid: 1174635424
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1174635424": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.3986468487780651,
#                             "C": 0.4550237188865273,
#                             "FA": 0.04465698469788718,
#                             "GA": 0.08769589396350859,
#                             "Start": 0.01017857480116797,
#                             "Stub": 0.003797978872843744
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Section, Alabama' with revid: 1166230919
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166230919": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.23354033909747077,
#                             "C": 0.4459597625004048,
#                             "FA": 0.00829780994477165,
#                             "GA": 0.060935935977168995,
#                             "Start": 0.2453684567752015,
#                             "Stub": 0.005897695704982239
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Selma, Alabama' with revid: 1143473983
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1143473983": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.3872272945504212,
#                             "C": 0.5603459186248059,
#                             "FA": 0.019432734847591056,
#                             "GA": 0.023808224861886183,
#                             "Start": 0.006878508953585513,
#                             "Stub": 0.0023073181617101974
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Sheffield, Alabama' with revid: 1178910007
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1178910007": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.25234201091022906,
#                             "C": 0.4991596002804535,
#                             "FA": 0.01812107240764367,
#                             "GA": 0.18946287527901748,
#                             "Start": 0.03571969254211071,
#                             "Stub": 0.005194748580545754
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Shiloh, DeKalb County, Alabama' with revid: 1166231236
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166231236": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.2390495785358417,
#                             "C": 0.3267328291967345,
#                             "FA": 0.00873810913802781,
#                             "GA": 0.17905732378598274,
#                             "Start": 0.233377756883799,
#                             "Stub": 0.013044402459614229
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Shorter, Alabama' with revid: 1167174337
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1167174337": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.23392235677712345,
#                             "C": 0.33900777940276877,
#                             "FA": 0.007380117192089983,
#                             "GA": 0.15359877363311625,
#                             "Start": 0.2588932361001356,
#                             "Stub": 0.007197736894765867
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Silas, Alabama' with revid: 1166231326
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166231326": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.18590164127792913,
#                             "C": 0.31997089578511145,
#                             "FA": 0.006875677310965407,
#                             "GA": 0.16290505199859617,
#                             "Start": 0.3167956419350415,
#                             "Stub": 0.007551091692356437
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Silverhill, Alabama' with revid: 1178521390
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1178521390": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.22980464512250065,
#                             "C": 0.4155840549294018,
#                             "FA": 0.008478268709491235,
#                             "GA": 0.19278756757347693,
#                             "Start": 0.14785288730985105,
#                             "Stub": 0.005492576355278172
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Sipsey, Alabama' with revid: 1166231394
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166231394": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "Start",
#                         "probability": {
#                             "B": 0.20085604267173363,
#                             "C": 0.3670107328481705,
#                             "FA": 0.0066596654307473,
#                             "GA": 0.038659106664581895,
#                             "Start": 0.3768529593117509,
#                             "Stub": 0.009961493073015838
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Skyline, Alabama' with revid: 1166231421
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166231421": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.23785923216690946,
#                             "C": 0.3869496165238068,
#                             "FA": 0.0075260035402075175,
#                             "GA": 0.08217250161087597,
#                             "Start": 0.27965958571710403,
#                             "Stub": 0.005833060441096138
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Slocomb, Alabama' with revid: 1165901938
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165901938": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "Start",
#                         "probability": {
#                             "B": 0.13965591167162142,
#                             "C": 0.3041962555122985,
#                             "FA": 0.005694640928536071,
#                             "GA": 0.048202495881212636,
#                             "Start": 0.49533269798708957,
#                             "Stub": 0.006917998019241726
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Smiths Station, Alabama' with revid: 1165901985
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165901985": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.16493005636735597,
#                             "C": 0.7560449518356488,
#                             "FA": 0.009998554846759647,
#                             "GA": 0.02816332232615674,
#                             "Start": 0.037689878892259956,
#                             "Stub": 0.0031732357318189023
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Snead, Alabama' with revid: 1166231481
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166231481": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "Start",
#                         "probability": {
#                             "B": 0.18886231657729585,
#                             "C": 0.3432258661065166,
#                             "FA": 0.006345435974470276,
#                             "GA": 0.056209802926855144,
#                             "Start": 0.398038572729136,
#                             "Stub": 0.007318005685726103
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Somerville, Alabama' with revid: 1166231524
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166231524": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.2592501470986727,
#                             "C": 0.38076975577545297,
#                             "FA": 0.009109927101391548,
#                             "GA": 0.23088815998845494,
#                             "Start": 0.11319136891309782,
#                             "Stub": 0.006790641122930027
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'South Vinemont, Alabama' with revid: 1166329815
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166329815": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "Start",
#                         "probability": {
#                             "B": 0.1485955369031952,
#                             "C": 0.3236397537491145,
#                             "FA": 0.006320122563836734,
#                             "GA": 0.16851043480157574,
#                             "Start": 0.34630772440772856,
#                             "Stub": 0.006626427574549228
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Southside, Alabama' with revid: 1165902345
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165902345": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.16401687070820473,
#                             "C": 0.42554146916937446,
#                             "FA": 0.006070557435108135,
#                             "GA": 0.09911395651554188,
#                             "Start": 0.300393207689826,
#                             "Stub": 0.0048639384819447375
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Spanish Fort, Alabama' with revid: 1178909983
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1178909983": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.2807445165603097,
#                             "C": 0.5794920837550589,
#                             "FA": 0.013182637694665041,
#                             "GA": 0.03872218561060065,
#                             "Start": 0.08208276996547245,
#                             "Stub": 0.005775806413893218
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Springville, Alabama' with revid: 1165902747
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165902747": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.20643264033158815,
#                             "C": 0.350554862529625,
#                             "FA": 0.009226891017669735,
#                             "GA": 0.33238946995990926,
#                             "Start": 0.09653729524635724,
#                             "Stub": 0.004858840914850576
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Steele, Alabama' with revid: 1166330411
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166330411": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.1865453355803826,
#                             "C": 0.38943620173511084,
#                             "FA": 0.007610747158872308,
#                             "GA": 0.07154841123521344,
#                             "Start": 0.33901396709949544,
#                             "Stub": 0.00584533719092517
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Stevenson, Alabama' with revid: 1165903151
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165903151": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.30633394348490117,
#                             "C": 0.4417337975845611,
#                             "FA": 0.022856820674222476,
#                             "GA": 0.18350737065555076,
#                             "Start": 0.04041004609089937,
#                             "Stub": 0.005158021509865115
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Sulligent, Alabama' with revid: 1165903367
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165903367": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.205411578504449,
#                             "C": 0.4243923722115992,
#                             "FA": 0.009768258847906205,
#                             "GA": 0.24759199182710206,
#                             "Start": 0.10749027630219232,
#                             "Stub": 0.005345522306751162
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Sumiton, Alabama' with revid: 1177623469
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1177623469": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.20294068894361839,
#                             "C": 0.5226947252451639,
#                             "FA": 0.007850343400736747,
#                             "GA": 0.025119609966894597,
#                             "Start": 0.2356285173940344,
#                             "Stub": 0.005766115049551749
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Summerdale, Alabama' with revid: 1166330782
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166330782": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.1838795766115506,
#                             "C": 0.6095857034529103,
#                             "FA": 0.011354436364959695,
#                             "GA": 0.10464653280467763,
#                             "Start": 0.08536383355435484,
#                             "Stub": 0.0051699172115469375
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Susan Moore, Alabama' with revid: 1166330933
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166330933": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.17055297735209327,
#                             "C": 0.4493672059498973,
#                             "FA": 0.009111152825182857,
#                             "GA": 0.12767664752000796,
#                             "Start": 0.23802394650861328,
#                             "Stub": 0.005268069844205221
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Sweet Water, Alabama' with revid: 1170589664
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1170589664": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "GA",
#                         "probability": {
#                             "B": 0.20566380184431213,
#                             "C": 0.16723616002236746,
#                             "FA": 0.005688054380964701,
#                             "GA": 0.5338698585624273,
#                             "Start": 0.08082476732607612,
#                             "Stub": 0.006717357863852427
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Sylacauga, Alabama' with revid: 1176796677
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1176796677": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.30965251999519144,
#                             "C": 0.6458695583295031,
#                             "FA": 0.012336127261285497,
#                             "GA": 0.012494048068896238,
#                             "Start": 0.016870736789379046,
#                             "Stub": 0.002777009555744774
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Sylvan Springs, Alabama' with revid: 1177624259
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1177624259": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "Start",
#                         "probability": {
#                             "B": 0.13809649621638395,
#                             "C": 0.37662441494426635,
#                             "FA": 0.005954085863948113,
#                             "GA": 0.030067959182641955,
#                             "Start": 0.4430118890417039,
#                             "Stub": 0.006245154751055691
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Sylvania, Alabama' with revid: 1166331023
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166331023": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "GA",
#                         "probability": {
#                             "B": 0.19155306865115862,
#                             "C": 0.30192646814014484,
#                             "FA": 0.007914870004164173,
#                             "GA": 0.32605093375506883,
#                             "Start": 0.1675768622600414,
#                             "Stub": 0.004977797189421944
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Talladega Springs, Alabama' with revid: 1166331095
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166331095": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.2229515170460266,
#                             "C": 0.345744338756855,
#                             "FA": 0.0074148550710671805,
#                             "GA": 0.074899892046873,
#                             "Start": 0.3412117567904332,
#                             "Stub": 0.007777640288745174
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Talladega, Alabama' with revid: 1165903654
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165903654": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.20093320960508293,
#                             "C": 0.5031966709331456,
#                             "FA": 0.028846614248278026,
#                             "GA": 0.2366557120383219,
#                             "Start": 0.02609286498276842,
#                             "Stub": 0.004274928192403239
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Tallassee, Alabama' with revid: 1151228134
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1151228134": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.3695939062489221,
#                             "C": 0.4201551917015146,
#                             "FA": 0.0534012096465369,
#                             "GA": 0.12621466657230365,
#                             "Start": 0.025469222790336605,
#                             "Stub": 0.00516580304038601
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Tarrant, Alabama' with revid: 1177783643
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1177783643": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.22536306137570325,
#                             "C": 0.46088799332904584,
#                             "FA": 0.014355729090964336,
#                             "GA": 0.2597286650382009,
#                             "Start": 0.0348260353762416,
#                             "Stub": 0.004838515789844142
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Taylor, Alabama' with revid: 1166331142
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1166331142": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.16700485347868976,
#                             "C": 0.4199651395824227,
#                             "FA": 0.0072300650894586245,
#                             "GA": 0.08784028756273915,
#                             "Start": 0.3116746085228198,
#                             "Stub": 0.006285045763870005
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Thomaston, Alabama' with revid: 1166331276
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
# ...
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Kake, Alaska' with revid: 1151995274
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1151995274": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.20947864077193812,
#                             "C": 0.41089188628575307,
#                             "FA": 0.010894232099933659,
#                             "GA": 0.2651287493336953,
#                             "Start": 0.0980719959844083,
#                             "Stub": 0.005534495524271628
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Kaktovik, Alaska' with revid: 1167643705
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1167643705": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.19027707437363034,
#                             "C": 0.3925281431720743,
#                             "FA": 0.017710179327100513,
#                             "GA": 0.2852882163973513,
#                             "Start": 0.10865640266439011,
#                             "Stub": 0.005539984065453436
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Kaltag, Alaska' with revid: 1165751831
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165751831": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.18138940800533782,
#                             "C": 0.36587548102362405,
#                             "FA": 0.012339403636542828,
#                             "GA": 0.2997151989109572,
#                             "Start": 0.1351128489313889,
#                             "Stub": 0.005567659492148959
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Kasaan, Alaska' with revid: 1165751881
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165751881": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "GA",
#                         "probability": {
#                             "B": 0.17579202787414044,
#                             "C": 0.2330675767463885,
#                             "FA": 0.010010530841561192,
#                             "GA": 0.5393450228461792,
#                             "Start": 0.037557635031542816,
#                             "Stub": 0.0042272066601877194
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Kenai, Alaska' with revid: 1179083176
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1179083176": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "GA",
#                         "probability": {
#                             "B": 0.20699372784232584,
#                             "C": 0.2912010345001407,
#                             "FA": 0.03845334778710753,
#                             "GA": 0.440308243380307,
#                             "Start": 0.018744973806677275,
#                             "Stub": 0.004298672683441621
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Ketchikan, Alaska' with revid: 1178738064
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1178738064": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "GA",
#                         "probability": {
#                             "B": 0.2597197914282729,
#                             "C": 0.08201258727907686,
#                             "FA": 0.15477821294356078,
#                             "GA": 0.48813331493159556,
#                             "Start": 0.011192351085927664,
#                             "Stub": 0.004163742331566284
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Kiana, Alaska' with revid: 1165752156
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165752156": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.2165402110370824,
#                             "C": 0.39000251240937234,
#                             "FA": 0.016875793421609424,
#                             "GA": 0.35026255794539957,
#                             "Start": 0.022091370825260803,
#                             "Stub": 0.004227554361275278
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'King Cove, Alaska' with revid: 1165752232
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165752232": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "GA",
#                         "probability": {
#                             "B": 0.15377415325215835,
#                             "C": 0.3177127868846337,
#                             "FA": 0.01241625101620137,
#                             "GA": 0.46548723686244026,
#                             "Start": 0.04645591875099789,
#                             "Stub": 0.00415365323356842
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Kivalina, Alaska' with revid: 1167306947
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1167306947": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "GA",
#                         "probability": {
#                             "B": 0.17417024228894032,
#                             "C": 0.13610698698746393,
#                             "FA": 0.054886486969455084,
#                             "GA": 0.6153715447162589,
#                             "Start": 0.01474135834855814,
#                             "Stub": 0.0047233806893237544
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Klawock, Alaska' with revid: 1165752344
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165752344": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.2619682199512975,
#                             "C": 0.5101562493105652,
#                             "FA": 0.021906787453412308,
#                             "GA": 0.11683906384230922,
#                             "Start": 0.08304094749942056,
#                             "Stub": 0.006088731942995238
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Kobuk, Alaska' with revid: 1165752375
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165752375": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.21682449735143122,
#                             "C": 0.402062604912099,
#                             "FA": 0.006992002432245275,
#                             "GA": 0.16757035685365862,
#                             "Start": 0.20143496605454222,
#                             "Stub": 0.005115572396023633
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Kodiak, Alaska' with revid: 1179271887
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1179271887": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "GA",
#                         "probability": {
#                             "B": 0.28421375307790475,
#                             "C": 0.22810776576678365,
#                             "FA": 0.07979958380077222,
#                             "GA": 0.39042100976305505,
#                             "Start": 0.013030653851604835,
#                             "Stub": 0.00442723373987932
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Kotlik, Alaska' with revid: 1165752392
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165752392": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.0961911702880504,
#                             "C": 0.5397670521290233,
#                             "FA": 0.004580698313693575,
#                             "GA": 0.04033778249115875,
#                             "Start": 0.31050480327102115,
#                             "Stub": 0.008618493507052646
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Kotzebue, Alaska' with revid: 1174601049
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1174601049": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "GA",
#                         "probability": {
#                             "B": 0.19584264927378872,
#                             "C": 0.1818292811547512,
#                             "FA": 0.16119573411815066,
#                             "GA": 0.4440062196660962,
#                             "Start": 0.012597387711714625,
#                             "Stub": 0.004528728075498632
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Koyuk, Alaska' with revid: 1178323608
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1178323608": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "Start",
#                         "probability": {
#                             "B": 0.1132775641776677,
#                             "C": 0.3218266877807051,
#                             "FA": 0.005882079098118966,
#                             "GA": 0.026227569948736876,
#                             "Start": 0.514710698797974,
#                             "Stub": 0.018075400196797414
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Koyukuk, Alaska' with revid: 1165752404
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165752404": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.17992494917026003,
#                             "C": 0.4246179455513842,
#                             "FA": 0.0068819055137518586,
#                             "GA": 0.156744580005312,
#                             "Start": 0.2264554967286393,
#                             "Stub": 0.005375123030652628
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Kupreanof, Alaska' with revid: 1165752424
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165752424": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "Start",
#                         "probability": {
#                             "B": 0.1840530496789553,
#                             "C": 0.3465461475893177,
#                             "FA": 0.0070388862601487795,
#                             "GA": 0.0679476230010388,
#                             "Start": 0.38573040345767284,
#                             "Stub": 0.008683890012866614
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Kwethluk, Alaska' with revid: 1165752432
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165752432": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "C",
#                         "probability": {
#                             "B": 0.2328620339515065,
#                             "C": 0.37638426795248003,
#                             "FA": 0.008050438155964321,
#                             "GA": 0.1381518584811818,
#                             "Start": 0.23576612633837832,
#                             "Stub": 0.008785275120489083
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
# Getting LiftWing ORES scores for 'Larsen Bay, Alaska' with revid: 1165889278
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1165889278": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "Start",
#                         "probability": {
#                             "B": 0.16731656803711822,
#                             "C": 0.3360327495749022,
#                             "FA": 0.00621863674135826,
#                             "GA": 0.064854145630743,
#                             "Start": 0.41438838846437437,
#                             "Stub": 0.011189511551504043
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }

# %% [markdown]
# We should note that no artciles were found without a quality score. Now we will write these scores and the articles to a csv file for storing

# %%
qual_cities = ores_score_file.keys()
qual_preds = ores_score_file.values()
predictions = pd.DataFrame()
predictions['article'] = qual_cities
predictions['prediction'] = qual_preds
predictions.to_csv("/content/drive/MyDrive/predictions (1).csv")

# %% [markdown]
# The API took 6-7 hours to run and failed multiple times. Hence, I kept on appending the results into a my dictionary for all those runs and eventually saved the list of dicts to a csv file.

# %% [markdown]
# Now we will read the file into the dataframe. We do this as it takes a very long time to re-run the APIs and hence after the initial run, whenever we need to access the data, we can directly pull it from the file

# %%
#Reading the ORES file
ores_score_file = pd.read_csv('/content/drive/My Drive/predictions (1).csv')

# %%
ores_score_file.head(10)
# Out:
#    Unnamed: 0                  article prediction
# 0           0       Abbeville, Alabama          C
# 1           1      Adamsville, Alabama          C
# 2           2         Addison, Alabama          C
# 3           3           Akron, Alabama         GA
# 4           4       Alabaster, Alabama          C
# 5           5     Albertville, Alabama          C
# 6           6  Alexander City, Alabama         GA
# 7           7      Aliceville, Alabama         GA
# 8           8         Allgood, Alabama          C
# 9           9         Altoona, Alabama          C

# %% [markdown]
# We identified a few entries which did not fit our criteria of being a  geographical location and hence we will remove those/

# %%
tbd = ['2020 United States census','2010 United States census','County (United States)','Population','Square mile','Federal Information Processing Standards',
       'American National Standards Institute','Geographic Names Information System','Wikipedia:Citation needed']
pred_drop = ores_score_file[ores_score_file['article'].isin(tbd)].index
ores_score_file.drop("Unnamed: 0",axis=1,inplace=True)
ores_score_file.drop(pred_drop,inplace=True)

# %% [markdown]
# We will now add the prediction and value as a new key-value pair in our dictionary

# %%
#Creating a temp dataframe so that the original does not get impacted with our experimentation
df = pd.DataFrame(ores_score_file)

df2 = pd.DataFrame(title_revid_list)

df3 = pd.merge(df, df2, left_on='article', right_on='title', how='left')
df3 = df3.drop_duplicates()

# %%
df3.head()
# Out:
#                article prediction                title   lastrevid
# 0   Abbeville, Alabama          C   Abbeville, Alabama  1171163550
# 2  Adamsville, Alabama          C  Adamsville, Alabama  1177621427
# 4     Addison, Alabama          C     Addison, Alabama  1168359898
# 6       Akron, Alabama         GA       Akron, Alabama  1165909508
# 8   Alabaster, Alabama          C   Alabaster, Alabama  1179139816

# %%
title_revid_list= df3.to_dict(orient='records')

# %%
title_revid_list
# Out:
# [{'article': 'Abbeville, Alabama',
#   'prediction': 'C',
#   'title': 'Abbeville, Alabama',
#   'lastrevid': 1171163550},
#  {'article': 'Adamsville, Alabama',
#   'prediction': 'C',
#   'title': 'Adamsville, Alabama',
#   'lastrevid': 1177621427},
#  {'article': 'Addison, Alabama',
#   'prediction': 'C',
#   'title': 'Addison, Alabama',
#   'lastrevid': 1168359898},
#  {'article': 'Akron, Alabama',
#   'prediction': 'GA',
#   'title': 'Akron, Alabama',
#   'lastrevid': 1165909508},
#  {'article': 'Alabaster, Alabama',
#   'prediction': 'C',
#   'title': 'Alabaster, Alabama',
#   'lastrevid': 1179139816},
#  {'article': 'Albertville, Alabama',
#   'prediction': 'C',
#   'title': 'Albertville, Alabama',
#   'lastrevid': 1179198677},
#  {'article': 'Alexander City, Alabama',
#   'prediction': 'GA',
#   'title': 'Alexander City, Alabama',
#   'lastrevid': 1179140073},
#  {'article': 'Aliceville, Alabama',
#   'prediction': 'GA',
#   'title': 'Aliceville, Alabama',
#   'lastrevid': 1167792390},
#  {'article': 'Allgood, Alabama',
#   'prediction': 'C',
#   'title': 'Allgood, Alabama',
#   'lastrevid': 1165909718},
#  {'article': 'Altoona, Alabama',
#   'prediction': 'C',
#   'title': 'Altoona, Alabama',
#   'lastrevid': 1165909823},
#  {'article': 'Andalusia, Alabama',
#   'prediction': 'C',
#   'title': 'Andalusia, Alabama',
#   'lastrevid': 1179141586},
#  {'article': 'Anderson, Lauderdale County, Alabama',
#   'prediction': 'Stub',
#   'title': 'Anderson, Lauderdale County, Alabama',
#   'lastrevid': 662691565},
#  {'article': 'Anniston, Alabama',
#   'prediction': 'C',
#   'title': 'Anniston, Alabama',
#   'lastrevid': 1176049382},
#  {'article': 'Arab, Alabama',
#   'prediction': 'C',
#   'title': 'Arab, Alabama',
#   'lastrevid': 1171375371},
#  {'article': 'Ardmore, Alabama',
#   'prediction': 'GA',
#   'title': 'Ardmore, Alabama',
#   'lastrevid': 1176903479},
#  {'article': 'Argo, Alabama',
#   'prediction': 'C',
#   'title': 'Argo, Alabama',
#   'lastrevid': 1177623964},
#  {'article': 'Ariton, Alabama',
#   'prediction': 'C',
#   'title': 'Ariton, Alabama',
#   'lastrevid': 1166014478},
#  {'article': 'Arley, Alabama',
#   'prediction': 'C',
#   'title': 'Arley, Alabama',
#   'lastrevid': 1166014498},
#  {'article': 'Ashford, Alabama',
#   'prediction': 'C',
#   'title': 'Ashford, Alabama',
#   'lastrevid': 1166014593},
#  {'article': 'Ashland, Alabama',
#   'prediction': 'C',
#   'title': 'Ashland, Alabama',
#   'lastrevid': 1174331705},
#  {'article': 'Ashville, Alabama',
#   'prediction': 'C',
#   'title': 'Ashville, Alabama',
#   'lastrevid': 1148844011},
#  {'article': 'Athens, Alabama',
#   'prediction': 'C',
#   'title': 'Athens, Alabama',
#   'lastrevid': 1175308807},
#  {'article': 'Atmore, Alabama',
#   'prediction': 'C',
#   'title': 'Atmore, Alabama',
#   'lastrevid': 1167926420},
#  {'article': 'Attalla, Alabama',
#   'prediction': 'C',
#   'title': 'Attalla, Alabama',
#   'lastrevid': 1165507856},
#  {'article': 'Auburn, Alabama',
#   'prediction': 'C',
#   'title': 'Auburn, Alabama',
#   'lastrevid': 1179878794},
#  {'article': 'Autaugaville, Alabama',
#   'prediction': 'C',
#   'title': 'Autaugaville, Alabama',
#   'lastrevid': 1166014815},
#  {'article': 'Avon, Alabama',
#   'prediction': 'Start',
#   'title': 'Avon, Alabama',
#   'lastrevid': 1166014861},
#  {'article': 'Babbie, Alabama',
#   'prediction': 'Start',
#   'title': 'Babbie, Alabama',
#   'lastrevid': 1168820544},
#  {'article': 'Baileyton, Alabama',
#   'prediction': 'C',
#   'title': 'Baileyton, Alabama',
#   'lastrevid': 1166014939},
#  {'article': 'Bakerhill, Alabama',
#   'prediction': 'Start',
#   'title': 'Bakerhill, Alabama',
#   'lastrevid': 1166014954},
#  {'article': 'Banks, Alabama',
#   'prediction': 'C',
#   'title': 'Banks, Alabama',
#   'lastrevid': 1166014997},
#  {'article': 'Bay Minette, Alabama',
#   'prediction': 'C',
#   'title': 'Bay Minette, Alabama',
#   'lastrevid': 1177963600},
#  {'article': 'Bayou La Batre, Alabama',
#   'prediction': 'C',
#   'title': 'Bayou La Batre, Alabama',
#   'lastrevid': 1177999052},
#  {'article': 'Bear Creek, Alabama',
#   'prediction': 'GA',
#   'title': 'Bear Creek, Alabama',
#   'lastrevid': 1166015184},
#  {'article': 'Beatrice, Alabama',
#   'prediction': 'C',
#   'title': 'Beatrice, Alabama',
#   'lastrevid': 1166015214},
#  {'article': 'Beaverton, Alabama',
#   'prediction': 'Start',
#   'title': 'Beaverton, Alabama',
#   'lastrevid': 1166015251},
#  {'article': 'Belk, Alabama',
#   'prediction': 'C',
#   'title': 'Belk, Alabama',
#   'lastrevid': 1166015313},
#  {'article': 'Benton, Alabama',
#   'prediction': 'C',
#   'title': 'Benton, Alabama',
#   'lastrevid': 1166015434},
#  {'article': 'Berlin, Alabama',
#   'prediction': 'Start',
#   'title': 'Berlin, Alabama',
#   'lastrevid': 1166015476},
#  {'article': 'Berry, Alabama',
#   'prediction': 'C',
#   'title': 'Berry, Alabama',
#   'lastrevid': 1166015515},
#  {'article': 'Bessemer, Alabama',
#   'prediction': 'C',
#   'title': 'Bessemer, Alabama',
#   'lastrevid': 1178999596},
#  {'article': 'Billingsley, Alabama',
#   'prediction': 'Start',
#   'title': 'Billingsley, Alabama',
#   'lastrevid': 1166015695},
#  {'article': 'Birmingham, Alabama',
#   'prediction': 'B',
#   'title': 'Birmingham, Alabama',
#   'lastrevid': 1179944837},
#  {'article': 'Black, Alabama',
#   'prediction': 'Start',
#   'title': 'Black, Alabama',
#   'lastrevid': 1166015772},
#  {'article': 'Blountsville, Alabama',
#   'prediction': 'GA',
#   'title': 'Blountsville, Alabama',
#   'lastrevid': 1105978061},
#  {'article': 'Blue Springs, Alabama',
#   'prediction': 'Start',
#   'title': 'Blue Springs, Alabama',
#   'lastrevid': 1166015902},
#  {'article': 'Boaz, Alabama',
#   'prediction': 'GA',
#   'title': 'Boaz, Alabama',
#   'lastrevid': 1177138566},
#  {'article': 'Boligee, Alabama',
#   'prediction': 'C',
#   'title': 'Boligee, Alabama',
#   'lastrevid': 1166015957},
#  {'article': 'Bon Air, Alabama',
#   'prediction': 'C',
#   'title': 'Bon Air, Alabama',
#   'lastrevid': 1166015981},
#  {'article': 'Brantley, Alabama',
#   'prediction': 'C',
#   'title': 'Brantley, Alabama',
#   'lastrevid': 1165814013},
#  {'article': 'Brent, Alabama',
#   'prediction': 'GA',
#   'title': 'Brent, Alabama',
#   'lastrevid': 1172245542},
#  {'article': 'Brewton, Alabama',
#   'prediction': 'GA',
#   'title': 'Brewton, Alabama',
#   'lastrevid': 1162427481},
#  {'article': 'Bridgeport, Alabama',
#   'prediction': 'GA',
#   'title': 'Bridgeport, Alabama',
#   'lastrevid': 1165537046},
#  {'article': 'Brighton, Alabama',
#   'prediction': 'C',
#   'title': 'Brighton, Alabama',
#   'lastrevid': 1177621572},
#  {'article': 'Brilliant, Alabama',
#   'prediction': 'GA',
#   'title': 'Brilliant, Alabama',
#   'lastrevid': 1166016323},
#  {'article': 'Brookside, Alabama',
#   'prediction': 'C',
#   'title': 'Brookside, Alabama',
#   'lastrevid': 1170769013},
#  {'article': 'Brookwood, Alabama',
#   'prediction': 'C',
#   'title': 'Brookwood, Alabama',
#   'lastrevid': 1178216914},
#  {'article': 'Brundidge, Alabama',
#   'prediction': 'C',
#   'title': 'Brundidge, Alabama',
#   'lastrevid': 1165537457},
#  {'article': 'Butler, Alabama',
#   'prediction': 'C',
#   'title': 'Butler, Alabama',
#   'lastrevid': 1144752979},
#  {'article': 'Calera, Alabama',
#   'prediction': 'C',
#   'title': 'Calera, Alabama',
#   'lastrevid': 1165537934},
#  {'article': 'Camden, Alabama',
#   'prediction': 'GA',
#   'title': 'Camden, Alabama',
#   'lastrevid': 1176316224},
#  {'article': 'Camp Hill, Alabama',
#   'prediction': 'C',
#   'title': 'Camp Hill, Alabama',
#   'lastrevid': 1166017104},
#  {'article': 'Carbon Hill, Alabama',
#   'prediction': 'C',
#   'title': 'Carbon Hill, Alabama',
#   'lastrevid': 1175376595},
#  {'article': 'Cardiff, Alabama',
#   'prediction': 'Start',
#   'title': 'Cardiff, Alabama',
#   'lastrevid': 1166017260},
#  {'article': 'Carolina, Alabama',
#   'prediction': 'Start',
#   'title': 'Carolina, Alabama',
#   'lastrevid': 1166017310},
#  {'article': 'Carrollton, Alabama',
#   'prediction': 'C',
#   'title': 'Carrollton, Alabama',
#   'lastrevid': 1096812581},
#  {'article': 'Castleberry, Alabama',
#   'prediction': 'Start',
#   'title': 'Castleberry, Alabama',
#   'lastrevid': 1166017442},
#  {'article': 'Cedar Bluff, Alabama',
#   'prediction': 'C',
#   'title': 'Cedar Bluff, Alabama',
#   'lastrevid': 1177836881},
#  {'article': 'Center Point, Alabama',
#   'prediction': 'C',
#   'title': 'Center Point, Alabama',
#   'lastrevid': 1174837569},
#  {'article': 'Centre, Alabama',
#   'prediction': 'C',
#   'title': 'Centre, Alabama',
#   'lastrevid': 1164314017},
#  {'article': 'Centreville, Alabama',
#   'prediction': 'C',
#   'title': 'Centreville, Alabama',
#   'lastrevid': 1172134285},
#  {'article': 'Chatom, Alabama',
#   'prediction': 'C',
#   'title': 'Chatom, Alabama',
#   'lastrevid': 1159488446},
#  {'article': 'Chelsea, Alabama',
#   'prediction': 'C',
#   'title': 'Chelsea, Alabama',
#   'lastrevid': 1165539092},
#  {'article': 'Cherokee, Alabama',
#   'prediction': 'C',
#   'title': 'Cherokee, Alabama',
#   'lastrevid': 1166017755},
#  {'article': 'Chickasaw, Alabama',
#   'prediction': 'C',
#   'title': 'Chickasaw, Alabama',
#   'lastrevid': 1165539195},
#  {'article': 'Childersburg, Alabama',
#   'prediction': 'GA',
#   'title': 'Childersburg, Alabama',
#   'lastrevid': 1165539227},
#  {'article': 'Citronelle, Alabama',
#   'prediction': 'C',
#   'title': 'Citronelle, Alabama',
#   'lastrevid': 1165539457},
#  {'article': 'Clanton, Alabama',
#   'prediction': 'GA',
#   'title': 'Clanton, Alabama',
#   'lastrevid': 1158612343},
#  {'article': 'Clay, Alabama',
#   'prediction': 'C',
#   'title': 'Clay, Alabama',
#   'lastrevid': 1177621993},
#  {'article': 'Clayhatchee, Alabama',
#   'prediction': 'Start',
#   'title': 'Clayhatchee, Alabama',
#   'lastrevid': 1166018079},
#  {'article': 'Clayton, Alabama',
#   'prediction': 'C',
#   'title': 'Clayton, Alabama',
#   'lastrevid': 1155236230},
#  {'article': 'Cleveland, Alabama',
#   'prediction': 'C',
#   'title': 'Cleveland, Alabama',
#   'lastrevid': 1168466910},
#  {'article': 'Clio, Alabama',
#   'prediction': 'Start',
#   'title': 'Clio, Alabama',
#   'lastrevid': 1165644511},
#  {'article': 'Coaling, Alabama',
#   'prediction': 'C',
#   'title': 'Coaling, Alabama',
#   'lastrevid': 1166018304},
#  {'article': 'Coffee Springs, Alabama',
#   'prediction': 'Start',
#   'title': 'Coffee Springs, Alabama',
#   'lastrevid': 1166018326},
#  {'article': 'Coffeeville, Alabama',
#   'prediction': 'C',
#   'title': 'Coffeeville, Alabama',
#   'lastrevid': 1166029689},
#  {'article': 'Coker, Alabama',
#   'prediction': 'Start',
#   'title': 'Coker, Alabama',
#   'lastrevid': 1166018360},
#  {'article': 'Collinsville, Alabama',
#   'prediction': 'C',
#   'title': 'Collinsville, Alabama',
#   'lastrevid': 1177947751},
#  {'article': 'Colony, Alabama',
#   'prediction': 'GA',
#   'title': 'Colony, Alabama',
#   'lastrevid': 1166018463},
#  {'article': 'Columbia, Alabama',
#   'prediction': 'C',
#   'title': 'Columbia, Alabama',
#   'lastrevid': 1166018475},
#  {'article': 'Columbiana, Alabama',
#   'prediction': 'C',
#   'title': 'Columbiana, Alabama',
#   'lastrevid': 1151357569},
#  {'article': 'Coosada, Alabama',
#   'prediction': 'C',
#   'title': 'Coosada, Alabama',
#   'lastrevid': 1172561590},
#  {'article': 'Cordova, Alabama',
#   'prediction': 'GA',
#   'title': 'Cordova, Alabama',
#   'lastrevid': 1165645181},
#  {'article': 'Cottonwood, Alabama',
#   'prediction': 'C',
#   'title': 'Cottonwood, Alabama',
#   'lastrevid': 1096812941},
#  {'article': 'County Line, Alabama',
#   'prediction': 'Start',
#   'title': 'County Line, Alabama',
#   'lastrevid': 1166018950},
#  {'article': 'Courtland, Alabama',
#   'prediction': 'GA',
#   'title': 'Courtland, Alabama',
#   'lastrevid': 1157580326},
#  {'article': 'Cowarts, Alabama',
#   'prediction': 'C',
#   'title': 'Cowarts, Alabama',
#   'lastrevid': 1166019003},
#  {'article': 'Creola, Alabama',
#   'prediction': 'GA',
#   'title': 'Creola, Alabama',
#   'lastrevid': 1139764613},
#  {'article': 'Crossville, Alabama',
#   'prediction': 'C',
#   'title': 'Crossville, Alabama',
#   'lastrevid': 1166066155},
#  {'article': 'Cuba, Alabama',
#   'prediction': 'C',
#   'title': 'Cuba, Alabama',
#   'lastrevid': 1175879685},
#  {'article': 'Cullman, Alabama',
#   'prediction': 'B',
#   'title': 'Cullman, Alabama',
#   'lastrevid': 1180017307},
#  {'article': 'Cusseta, Alabama',
#   'prediction': 'Start',
#   'title': 'Cusseta, Alabama',
#   'lastrevid': 1172824345},
#  {'article': 'Dadeville, Alabama',
#   'prediction': 'C',
#   'title': 'Dadeville, Alabama',
#   'lastrevid': 1158607851},
#  {'article': 'Daleville, Alabama',
#   'prediction': 'GA',
#   'title': 'Daleville, Alabama',
#   'lastrevid': 1154496305},
#  {'article': 'Daphne, Alabama',
#   'prediction': 'FA',
#   'title': 'Daphne, Alabama',
#   'lastrevid': 1165646156},
#  {'article': 'Dauphin Island, Alabama',
#   'prediction': 'B',
#   'title': 'Dauphin Island, Alabama',
#   'lastrevid': 1174226588},
#  {'article': 'Daviston, Alabama',
#   'prediction': 'C',
#   'title': 'Daviston, Alabama',
#   'lastrevid': 1166066473},
#  {'article': 'Dayton, Alabama',
#   'prediction': 'C',
#   'title': 'Dayton, Alabama',
#   'lastrevid': 1166066487},
#  {'article': 'Deatsville, Alabama',
#   'prediction': 'C',
#   'title': 'Deatsville, Alabama',
#   'lastrevid': 1166066515},
#  {'article': 'Decatur, Alabama',
#   'prediction': 'C',
#   'title': 'Decatur, Alabama',
#   'lastrevid': 1178063438},
#  {'article': 'Demopolis, Alabama',
#   'prediction': 'B',
#   'title': 'Demopolis, Alabama',
#   'lastrevid': 1161394946},
#  {'article': 'Detroit, Alabama',
#   'prediction': 'Start',
#   'title': 'Detroit, Alabama',
#   'lastrevid': 1166066756},
#  {'article': 'Dodge City, Alabama',
#   'prediction': 'Start',
#   'title': 'Dodge City, Alabama',
#   'lastrevid': 1166066982},
#  {'article': 'Dora, Alabama',
#   'prediction': 'C',
#   'title': 'Dora, Alabama',
#   'lastrevid': 1165647022},
#  {'article': 'Dothan, Alabama',
#   'prediction': 'B',
#   'title': 'Dothan, Alabama',
#   'lastrevid': 1179231968},
#  {'article': 'Double Springs, Alabama',
#   'prediction': 'C',
#   'title': 'Double Springs, Alabama',
#   'lastrevid': 1159024876},
#  {'article': 'Douglas, Alabama',
#   'prediction': 'GA',
#   'title': 'Douglas, Alabama',
#   'lastrevid': 1166067023},
#  {'article': 'Dozier, Alabama',
#   'prediction': 'Start',
#   'title': 'Dozier, Alabama',
#   'lastrevid': 1096813187},
#  {'article': 'Dutton, Alabama',
#   'prediction': 'C',
#   'title': 'Dutton, Alabama',
#   'lastrevid': 1166067175},
#  {'article': 'East Brewton, Alabama',
#   'prediction': 'C',
#   'title': 'East Brewton, Alabama',
#   'lastrevid': 1165647609},
#  {'article': 'Eclectic, Alabama',
#   'prediction': 'C',
#   'title': 'Eclectic, Alabama',
#   'lastrevid': 1145048302},
#  {'article': 'Edwardsville, Alabama',
#   'prediction': 'C',
#   'title': 'Edwardsville, Alabama',
#   'lastrevid': 1166067508},
#  {'article': 'Elba, Alabama',
#   'prediction': 'C',
#   'title': 'Elba, Alabama',
#   'lastrevid': 1163400900},
#  {'article': 'Elberta, Alabama',
#   'prediction': 'C',
#   'title': 'Elberta, Alabama',
#   'lastrevid': 1175895043},
#  {'article': 'Eldridge, Alabama',
#   'prediction': 'Start',
#   'title': 'Eldridge, Alabama',
#   'lastrevid': 1178177223},
#  {'article': 'Elkmont, Alabama',
#   'prediction': 'C',
#   'title': 'Elkmont, Alabama',
#   'lastrevid': 1176555126},
#  {'article': 'Elmore, Alabama',
#   'prediction': 'C',
#   'title': 'Elmore, Alabama',
#   'lastrevid': 1166067658},
#  {'article': 'Emelle, Alabama',
#   'prediction': 'C',
#   'title': 'Emelle, Alabama',
#   'lastrevid': 1158753175},
#  {'article': 'Enterprise, Alabama',
#   'prediction': 'C',
#   'title': 'Enterprise, Alabama',
#   'lastrevid': 1160273773},
#  {'article': 'Epes, Alabama',
#   'prediction': 'C',
#   'title': 'Epes, Alabama',
#   'lastrevid': 1166067751},
#  {'article': 'Ethelsville, Alabama',
#   'prediction': 'Start',
#   'title': 'Ethelsville, Alabama',
#   'lastrevid': 1166067848},
#  {'article': 'Eufaula, Alabama',
#   'prediction': 'GA',
#   'title': 'Eufaula, Alabama',
#   'lastrevid': 1160493671},
#  {'article': 'Eutaw, Alabama',
#   'prediction': 'C',
#   'title': 'Eutaw, Alabama',
#   'lastrevid': 1158611853},
#  {'article': 'Eva, Alabama',
#   'prediction': 'GA',
#   'title': 'Eva, Alabama',
#   'lastrevid': 1166067877},
#  {'article': 'Evergreen, Conecuh County, Alabama',
#   'prediction': 'C',
#   'title': 'Evergreen, Conecuh County, Alabama',
#   'lastrevid': 1158611789},
#  {'article': 'Excel, Alabama',
#   'prediction': 'C',
#   'title': 'Excel, Alabama',
#   'lastrevid': 1166067942},
#  {'article': 'Fairfield, Alabama',
#   'prediction': 'C',
#   'title': 'Fairfield, Alabama',
#   'lastrevid': 1177239572},
#  {'article': 'Fairhope, Alabama',
#   'prediction': 'C',
#   'title': 'Fairhope, Alabama',
#   'lastrevid': 1173963070},
#  {'article': 'Fairview, Alabama',
#   'prediction': 'C',
#   'title': 'Fairview, Alabama',
#   'lastrevid': 1166068021},
#  {'article': 'Falkville, Alabama',
#   'prediction': 'GA',
#   'title': 'Falkville, Alabama',
#   'lastrevid': 1166068054},
#  {'article': 'Faunsdale, Alabama',
#   'prediction': 'GA',
#   'title': 'Faunsdale, Alabama',
#   'lastrevid': 1167428050},
#  {'article': 'Fayette, Alabama',
#   'prediction': 'C',
#   'title': 'Fayette, Alabama',
#   'lastrevid': 1142947111},
#  {'article': 'Five Points, Alabama',
#   'prediction': 'C',
#   'title': 'Five Points, Alabama',
#   'lastrevid': 1166068289},
#  {'article': 'Flomaton, Alabama',
#   'prediction': 'C',
#   'title': 'Flomaton, Alabama',
#   'lastrevid': 1166244039},
#  {'article': 'Florala, Alabama',
#   'prediction': 'C',
#   'title': 'Florala, Alabama',
#   'lastrevid': 1166068321},
#  {'article': 'Florence, Alabama',
#   'prediction': 'C',
#   'title': 'Florence, Alabama',
#   'lastrevid': 1178304592},
#  {'article': 'Foley, Alabama',
#   'prediction': 'C',
#   'title': 'Foley, Alabama',
#   'lastrevid': 1166414056},
#  {'article': 'Forkland, Alabama',
#   'prediction': 'C',
#   'title': 'Forkland, Alabama',
#   'lastrevid': 1166068466},
#  {'article': 'Fort Deposit, Alabama',
#   'prediction': 'C',
#   'title': 'Fort Deposit, Alabama',
#   'lastrevid': 1177020476},
#  {'article': 'Fort Payne, Alabama',
#   'prediction': 'GA',
#   'title': 'Fort Payne, Alabama',
#   'lastrevid': 1172551841},
#  {'article': 'Franklin, Alabama',
#   'prediction': 'GA',
#   'title': 'Franklin, Alabama',
#   'lastrevid': 1166068620},
#  {'article': 'Frisco City, Alabama',
#   'prediction': 'C',
#   'title': 'Frisco City, Alabama',
#   'lastrevid': 1166068863},
#  {'article': 'Fruithurst, Alabama',
#   'prediction': 'Start',
#   'title': 'Fruithurst, Alabama',
#   'lastrevid': 1166068877},
#  {'article': 'Fulton, Alabama',
#   'prediction': 'Start',
#   'title': 'Fulton, Alabama',
#   'lastrevid': 1166068885},
#  {'article': 'Fultondale, Alabama',
#   'prediction': 'C',
#   'title': 'Fultondale, Alabama',
#   'lastrevid': 1165840932},
#  {'article': 'Fyffe, Alabama',
#   'prediction': 'C',
#   'title': 'Fyffe, Alabama',
#   'lastrevid': 1160192215},
#  {'article': 'Gadsden, Alabama',
#   'prediction': 'C',
#   'title': 'Gadsden, Alabama',
#   'lastrevid': 1177146243},
#  {'article': 'Gainesville, Alabama',
#   'prediction': 'C',
#   'title': 'Gainesville, Alabama',
#   'lastrevid': 1166068936},
#  {'article': 'Gantt, Alabama',
#   'prediction': 'Start',
#   'title': 'Gantt, Alabama',
#   'lastrevid': 1166068957},
#  {'article': 'Garden City, Alabama',
#   'prediction': 'C',
#   'title': 'Garden City, Alabama',
#   'lastrevid': 1166068968},
#  {'article': 'Gardendale, Alabama',
#   'prediction': 'C',
#   'title': 'Gardendale, Alabama',
#   'lastrevid': 1175530987},
#  {'article': 'Gaylesville, Alabama',
#   'prediction': 'C',
#   'title': 'Gaylesville, Alabama',
#   'lastrevid': 1166069113},
#  {'article': 'Geiger, Alabama',
#   'prediction': 'Start',
#   'title': 'Geiger, Alabama',
#   'lastrevid': 1166069121},
#  {'article': 'Geneva, Alabama',
#   'prediction': 'C',
#   'title': 'Geneva, Alabama',
#   'lastrevid': 1179698088},
#  {'article': 'Georgiana, Alabama',
#   'prediction': 'Start',
#   'title': 'Georgiana, Alabama',
#   'lastrevid': 1178540000},
#  {'article': 'Geraldine, Alabama',
#   'prediction': 'C',
#   'title': 'Geraldine, Alabama',
#   'lastrevid': 1166069211},
#  {'article': 'Gilbertown, Alabama',
#   'prediction': 'C',
#   'title': 'Gilbertown, Alabama',
#   'lastrevid': 1166069407},
#  {'article': 'Glen Allen, Alabama',
#   'prediction': 'C',
#   'title': 'Glen Allen, Alabama',
#   'lastrevid': 1166069457},
#  {'article': 'Glencoe, Alabama',
#   'prediction': 'C',
#   'title': 'Glencoe, Alabama',
#   'lastrevid': 1165748058},
#  {'article': 'Glenwood, Alabama',
#   'prediction': 'Start',
#   'title': 'Glenwood, Alabama',
#   'lastrevid': 1096814086},
#  {'article': 'Goldville, Alabama',
#   'prediction': 'Start',
#   'title': 'Goldville, Alabama',
#   'lastrevid': 1177535939},
#  {'article': 'Good Hope, Alabama',
#   'prediction': 'C',
#   'title': 'Good Hope, Alabama',
#   'lastrevid': 1165748200},
#  {'article': 'Goodwater, Alabama',
#   'prediction': 'C',
#   'title': 'Goodwater, Alabama',
#   'lastrevid': 1166069571},
#  {'article': 'Gordo, Alabama',
#   'prediction': 'C',
#   'title': 'Gordo, Alabama',
#   'lastrevid': 1176908359},
#  {'article': 'Gordon, Alabama',
#   'prediction': 'C',
#   'title': 'Gordon, Alabama',
#   'lastrevid': 1166069580},
#  {'article': 'Gordonville, Alabama',
#   'prediction': 'C',
#   'title': 'Gordonville, Alabama',
#   'lastrevid': 1166069594},
#  {'article': 'Goshen, Alabama',
#   'prediction': 'C',
#   'title': 'Goshen, Alabama',
#   'lastrevid': 1166069601},
#  {'article': 'Grant, Alabama',
#   'prediction': 'GA',
#   'title': 'Grant, Alabama',
#   'lastrevid': 1166069728},
#  {'article': 'Graysville, Alabama',
#   'prediction': 'C',
#   'title': 'Graysville, Alabama',
#   'lastrevid': 1177622200},
#  {'article': 'Greensboro, Alabama',
#   'prediction': 'C',
#   'title': 'Greensboro, Alabama',
#   'lastrevid': 1172134373},
#  {'article': 'Greenville, Alabama',
#   'prediction': 'C',
#   'title': 'Greenville, Alabama',
#   'lastrevid': 1171417115},
#  {'article': 'Grimes, Alabama',
#   'prediction': 'Start',
#   'title': 'Grimes, Alabama',
#   'lastrevid': 1166180119},
#  {'article': 'Grove Hill, Alabama',
#   'prediction': 'C',
#   'title': 'Grove Hill, Alabama',
#   'lastrevid': 1144754911},
#  {'article': 'Guin, Alabama',
#   'prediction': 'C',
#   'title': 'Guin, Alabama',
#   'lastrevid': 1173001379},
#  {'article': 'Gulf Shores, Alabama',
#   'prediction': 'C',
#   'title': 'Gulf Shores, Alabama',
#   'lastrevid': 1174473447},
#  {'article': 'Guntersville, Alabama',
#   'prediction': 'C',
#   'title': 'Guntersville, Alabama',
#   'lastrevid': 1169878221},
#  {'article': 'Gurley, Alabama',
#   'prediction': 'C',
#   'title': 'Gurley, Alabama',
#   'lastrevid': 1173078483},
#  {'article': 'Gu-Win, Alabama',
#   'prediction': 'C',
#   'title': 'Gu-Win, Alabama',
#   'lastrevid': 1175521277},
#  {'article': 'Hackleburg, Alabama',
#   'prediction': 'GA',
#   'title': 'Hackleburg, Alabama',
#   'lastrevid': 1167581471},
#  {'article': 'Haleburg, Alabama',
#   'prediction': 'C',
#   'title': 'Haleburg, Alabama',
#   'lastrevid': 1166180281},
#  {'article': 'Haleyville, Alabama',
#   'prediction': 'GA',
#   'title': 'Haleyville, Alabama',
#   'lastrevid': 1168590141},
#  {'article': 'Hamilton, Alabama',
#   'prediction': 'C',
#   'title': 'Hamilton, Alabama',
#   'lastrevid': 1170634832},
#  {'article': 'Hammondville, Alabama',
#   'prediction': 'C',
#   'title': 'Hammondville, Alabama',
#   'lastrevid': 1166180369},
#  {'article': 'Hanceville, Alabama',
#   'prediction': 'C',
#   'title': 'Hanceville, Alabama',
#   'lastrevid': 1169612470},
#  {'article': 'Harpersville, Alabama',
#   'prediction': 'C',
#   'title': 'Harpersville, Alabama',
#   'lastrevid': 1177953234},
#  {'article': 'Hartford, Alabama',
#   'prediction': 'C',
#   'title': 'Hartford, Alabama',
#   'lastrevid': 1165749307},
#  {'article': 'Hartselle, Alabama',
#   'prediction': 'C',
#   'title': 'Hartselle, Alabama',
#   'lastrevid': 1165749341},
#  {'article': 'Hayden, Alabama',
#   'prediction': 'C',
#   'title': 'Hayden, Alabama',
#   'lastrevid': 1166180747},
#  {'article': 'Hayneville, Alabama',
#   'prediction': 'C',
#   'title': 'Hayneville, Alabama',
#   'lastrevid': 1166180764},
#  {'article': 'Headland, Alabama',
#   'prediction': 'C',
#   'title': 'Headland, Alabama',
#   'lastrevid': 1168369252},
#  {'article': 'Heath, Alabama',
#   'prediction': 'Start',
#   'title': 'Heath, Alabama',
#   'lastrevid': 1166180800},
#  {'article': 'Heflin, Alabama',
#   'prediction': 'C',
#   'title': 'Heflin, Alabama',
#   'lastrevid': 1176321971},
#  {'article': 'Helena, Alabama',
#   'prediction': 'C',
#   'title': 'Helena, Alabama',
#   'lastrevid': 1177702091},
#  {'article': 'Henagar, Alabama',
#   'prediction': 'C',
#   'title': 'Henagar, Alabama',
#   'lastrevid': 1165749718},
#  {'article': 'Highland Lake, Alabama',
#   'prediction': 'Start',
#   'title': 'Highland Lake, Alabama',
#   'lastrevid': 1166180993},
#  {'article': 'Hillsboro, Alabama',
#   'prediction': 'C',
#   'title': 'Hillsboro, Alabama',
#   'lastrevid': 1166181055},
#  {'article': 'Hobson City, Alabama',
#   'prediction': 'C',
#   'title': 'Hobson City, Alabama',
#   'lastrevid': 1166181157},
#  {'article': 'Hodges, Alabama',
#   'prediction': 'C',
#   'title': 'Hodges, Alabama',
#   'lastrevid': 1166181162},
#  {'article': 'Hokes Bluff, Alabama',
#   'prediction': 'C',
#   'title': 'Hokes Bluff, Alabama',
#   'lastrevid': 1165750177},
#  {'article': 'Holly Pond, Alabama',
#   'prediction': 'C',
#   'title': 'Holly Pond, Alabama',
#   'lastrevid': 1166181271},
#  {'article': 'Hollywood, Alabama',
#   'prediction': 'C',
#   'title': 'Hollywood, Alabama',
#   'lastrevid': 1166181286},
#  {'article': 'Homewood, Alabama',
#   'prediction': 'GA',
#   'title': 'Homewood, Alabama',
#   'lastrevid': 1177622299},
#  {'article': 'Hoover, Alabama',
#   'prediction': 'C',
#   'title': 'Hoover, Alabama',
#   'lastrevid': 1177622412},
#  {'article': 'Horn Hill, Alabama',
#   'prediction': 'Start',
#   'title': 'Horn Hill, Alabama',
#   'lastrevid': 1166181398},
#  {'article': 'Hueytown, Alabama',
#   'prediction': 'C',
#   'title': 'Hueytown, Alabama',
#   'lastrevid': 1177622536},
#  {'article': 'Huntsville, Alabama',
#   'prediction': 'FA',
#   'title': 'Huntsville, Alabama',
#   'lastrevid': 1180130440},
#  {'article': 'Hurtsboro, Alabama',
#   'prediction': 'C',
#   'title': 'Hurtsboro, Alabama',
#   'lastrevid': 1096814754},
#  {'article': 'Hytop, Alabama',
#   'prediction': 'Start',
#   'title': 'Hytop, Alabama',
#   'lastrevid': 1166181602},
#  {'article': 'Ider, Alabama',
#   'prediction': 'C',
#   'title': 'Ider, Alabama',
#   'lastrevid': 1166181612},
#  {'article': 'Indian Springs Village, Alabama',
#   'prediction': 'C',
#   'title': 'Indian Springs Village, Alabama',
#   'lastrevid': 1166181665},
#  {'article': 'Irondale, Alabama',
#   'prediction': 'C',
#   'title': 'Irondale, Alabama',
#   'lastrevid': 1169440818},
#  {'article': 'Jackson, Alabama',
#   'prediction': 'C',
#   'title': 'Jackson, Alabama',
#   'lastrevid': 1165750992},
#  {'article': "Jackson's Gap, Alabama",
#   'prediction': 'Start',
#   'title': "Jackson's Gap, Alabama",
#   'lastrevid': 1166181798},
#  {'article': 'Jacksonville, Alabama',
#   'prediction': 'C',
#   'title': 'Jacksonville, Alabama',
#   'lastrevid': 1175988040},
#  {'article': 'Jasper, Alabama',
#   'prediction': 'C',
#   'title': 'Jasper, Alabama',
#   'lastrevid': 1174380579},
#  {'article': 'Jemison, Alabama',
#   'prediction': 'C',
#   'title': 'Jemison, Alabama',
#   'lastrevid': 1165751151},
#  {'article': 'Kansas, Alabama',
#   'prediction': 'Start',
#   'title': 'Kansas, Alabama',
#   'lastrevid': 1166182143},
#  {'article': 'Kellyton, Alabama',
#   'prediction': 'Stub',
#   'title': 'Kellyton, Alabama',
#   'lastrevid': 1166182186},
#  {'article': 'Kennedy, Alabama',
#   'prediction': 'Start',
#   'title': 'Kennedy, Alabama',
#   'lastrevid': 1166182247},
#  {'article': 'Killen, Alabama',
#   'prediction': 'C',
#   'title': 'Killen, Alabama',
#   'lastrevid': 1166182386},
#  {'article': 'Kimberly, Alabama',
#   'prediction': 'C',
#   'title': 'Kimberly, Alabama',
#   'lastrevid': 1177622633},
#  {'article': 'Kinsey, Alabama',
#   'prediction': 'C',
#   'title': 'Kinsey, Alabama',
#   'lastrevid': 1166182487},
#  {'article': 'Kinston, Alabama',
#   'prediction': 'C',
#   'title': 'Kinston, Alabama',
#   'lastrevid': 1166182489},
#  {'article': 'LaFayette, Alabama',
#   'prediction': 'C',
#   'title': 'LaFayette, Alabama',
#   'lastrevid': 1165752571},
#  {'article': 'Lake View, Alabama',
#   'prediction': 'C',
#   'title': 'Lake View, Alabama',
#   'lastrevid': 1170831381},
#  {'article': 'Lakeview, Alabama',
#   'prediction': 'Start',
#   'title': 'Lakeview, Alabama',
#   'lastrevid': 1166205391},
#  {'article': 'Lanett, Alabama',
#   'prediction': 'C',
#   'title': 'Lanett, Alabama',
#   'lastrevid': 1165889187},
#  {'article': 'Langston, Alabama',
#   'prediction': 'C',
#   'title': 'Langston, Alabama',
#   'lastrevid': 1171521067},
#  {'article': 'Leeds, Alabama',
#   'prediction': 'C',
#   'title': 'Leeds, Alabama',
#   'lastrevid': 1179531175},
#  {'article': 'Leesburg, Alabama',
#   'prediction': 'C',
#   'title': 'Leesburg, Alabama',
#   'lastrevid': 1166205728},
#  {'article': 'Leighton, Alabama',
#   'prediction': 'C',
#   'title': 'Leighton, Alabama',
#   'lastrevid': 1148926606},
#  {'article': 'Lester, Alabama',
#   'prediction': 'Start',
#   'title': 'Lester, Alabama',
#   'lastrevid': 1166205815},
#  {'article': 'Level Plains, Alabama',
#   'prediction': 'Start',
#   'title': 'Level Plains, Alabama',
#   'lastrevid': 1165890044},
#  {'article': 'Lexington, Alabama',
#   'prediction': 'Start',
#   'title': 'Lexington, Alabama',
#   'lastrevid': 1166205880},
#  {'article': 'Libertyville, Alabama',
#   'prediction': 'Start',
#   'title': 'Libertyville, Alabama',
#   'lastrevid': 1166205930},
#  {'article': 'Lincoln, Alabama',
#   'prediction': 'C',
#   'title': 'Lincoln, Alabama',
#   'lastrevid': 1165890317},
#  {'article': 'Linden, Alabama',
#   'prediction': 'GA',
#   'title': 'Linden, Alabama',
#   'lastrevid': 1170891816},
#  {'article': 'Lineville, Alabama',
#   'prediction': 'GA',
#   'title': 'Lineville, Alabama',
#   'lastrevid': 1165890459},
#  {'article': 'Lipscomb, Alabama',
#   'prediction': 'C',
#   'title': 'Lipscomb, Alabama',
#   'lastrevid': 1177622747},
#  {'article': 'Lisman, Alabama',
#   'prediction': 'C',
#   'title': 'Lisman, Alabama',
#   'lastrevid': 1166206088},
#  {'article': 'Littleville, Alabama',
#   'prediction': 'Start',
#   'title': 'Littleville, Alabama',
#   'lastrevid': 1166206172},
#  {'article': 'Livingston, Alabama',
#   'prediction': 'C',
#   'title': 'Livingston, Alabama',
#   'lastrevid': 1165891122},
#  {'article': 'Loachapoka, Alabama',
#   'prediction': 'C',
#   'title': 'Loachapoka, Alabama',
#   'lastrevid': 1166206211},
#  {'article': 'Lockhart, Alabama',
#   'prediction': 'C',
#   'title': 'Lockhart, Alabama',
#   'lastrevid': 1166206220},
#  {'article': 'Locust Fork, Alabama',
#   'prediction': 'C',
#   'title': 'Locust Fork, Alabama',
#   'lastrevid': 1173287337},
#  {'article': 'Louisville, Alabama',
#   'prediction': 'Start',
#   'title': 'Louisville, Alabama',
#   'lastrevid': 1166206343},
#  {'article': 'Lowndesboro, Alabama',
#   'prediction': 'C',
#   'title': 'Lowndesboro, Alabama',
#   'lastrevid': 1166206408},
#  {'article': 'Loxley, Alabama',
#   'prediction': 'C',
#   'title': 'Loxley, Alabama',
#   'lastrevid': 1170361974},
#  {'article': 'Luverne, Alabama',
#   'prediction': 'C',
#   'title': 'Luverne, Alabama',
#   'lastrevid': 1173068585},
#  {'article': 'Lynn, Alabama',
#   'prediction': 'Start',
#   'title': 'Lynn, Alabama',
#   'lastrevid': 1166206561},
#  {'article': 'Madison, Alabama',
#   'prediction': 'C',
#   'title': 'Madison, Alabama',
#   'lastrevid': 1177703025},
#  {'article': 'Madrid, Alabama',
#   'prediction': 'C',
#   'title': 'Madrid, Alabama',
#   'lastrevid': 1166206649},
#  {'article': 'Magnolia Springs, Alabama',
#   'prediction': 'GA',
#   'title': 'Magnolia Springs, Alabama',
#   'lastrevid': 1166206656},
#  {'article': 'Malvern, Alabama',
#   'prediction': 'C',
#   'title': 'Malvern, Alabama',
#   'lastrevid': 1166206718},
#  {'article': 'Maplesville, Alabama',
#   'prediction': 'C',
#   'title': 'Maplesville, Alabama',
#   'lastrevid': 1166206829},
#  {'article': 'Margaret, Alabama',
#   'prediction': 'C',
#   'title': 'Margaret, Alabama',
#   'lastrevid': 1165892174},
#  {'article': 'Marion, Alabama',
#   'prediction': 'GA',
#   'title': 'Marion, Alabama',
#   'lastrevid': 1165892206},
#  {'article': 'Maytown, Alabama',
#   'prediction': 'Start',
#   'title': 'Maytown, Alabama',
#   'lastrevid': 1166207284},
#  {'article': 'McIntosh, Alabama',
#   'prediction': 'C',
#   'title': 'McIntosh, Alabama',
#   'lastrevid': 1176350576},
#  {'article': 'McKenzie, Alabama',
#   'prediction': 'Start',
#   'title': 'McKenzie, Alabama',
#   'lastrevid': 1166207344},
#  {'article': 'McMullen, Alabama',
#   'prediction': 'Start',
#   'title': 'McMullen, Alabama',
#   'lastrevid': 1166207363},
#  {'article': 'Memphis, Alabama',
#   'prediction': 'Start',
#   'title': 'Memphis, Alabama',
#   'lastrevid': 1166207484},
#  {'article': 'Mentone, Alabama',
#   'prediction': 'GA',
#   'title': 'Mentone, Alabama',
#   'lastrevid': 1166207510},
#  {'article': 'Midfield, Alabama',
#   'prediction': 'C',
#   'title': 'Midfield, Alabama',
#   'lastrevid': 1165893352},
#  {'article': 'Midland City, Alabama',
#   'prediction': 'C',
#   'title': 'Midland City, Alabama',
#   'lastrevid': 1166207749},
#  {'article': 'Midway, Alabama',
#   'prediction': 'C',
#   'title': 'Midway, Alabama',
#   'lastrevid': 1158753496},
#  {'article': 'Millbrook, Alabama',
#   'prediction': 'C',
#   'title': 'Millbrook, Alabama',
#   'lastrevid': 1178021676},
#  {'article': 'Millport, Alabama',
#   'prediction': 'C',
#   'title': 'Millport, Alabama',
#   'lastrevid': 1166207935},
#  {'article': 'Millry, Alabama',
#   'prediction': 'Start',
#   'title': 'Millry, Alabama',
#   'lastrevid': 1166207936},
#  {'article': 'Mobile, Alabama',
#   'prediction': 'GA',
#   'title': 'Mobile, Alabama',
#   'lastrevid': 1178152366},
#  {'article': 'Monroeville, Alabama',
#   'prediction': 'C',
#   'title': 'Monroeville, Alabama',
#   'lastrevid': 1172371452},
#  {'article': 'Montevallo, Alabama',
#   'prediction': 'C',
#   'title': 'Montevallo, Alabama',
#   'lastrevid': 1177552745},
#  {'article': 'Montgomery, Alabama',
#   'prediction': 'GA',
#   'title': 'Montgomery, Alabama',
#   'lastrevid': 1174537991},
#  {'article': 'Moody, Alabama',
#   'prediction': 'C',
#   'title': 'Moody, Alabama',
#   'lastrevid': 1179508395},
#  {'article': 'Mooresville, Alabama',
#   'prediction': 'C',
#   'title': 'Mooresville, Alabama',
#   'lastrevid': 1169255573},
#  {'article': 'Morris, Alabama',
#   'prediction': 'C',
#   'title': 'Morris, Alabama',
#   'lastrevid': 1177624137},
#  {'article': 'Mosses, Alabama',
#   'prediction': 'C',
#   'title': 'Mosses, Alabama',
#   'lastrevid': 1175025748},
#  {'article': 'Moulton, Alabama',
#   'prediction': 'C',
#   'title': 'Moulton, Alabama',
#   'lastrevid': 1165894467},
#  {'article': 'Moundville, Alabama',
#   'prediction': 'C',
#   'title': 'Moundville, Alabama',
#   'lastrevid': 1166208667},
#  {'article': 'Mount Vernon, Alabama',
#   'prediction': 'GA',
#   'title': 'Mount Vernon, Alabama',
#   'lastrevid': 1166208775},
#  {'article': 'Mountain Brook, Alabama',
#   'prediction': 'C',
#   'title': 'Mountain Brook, Alabama',
#   'lastrevid': 1172621297},
#  {'article': 'Mulga, Alabama',
#   'prediction': 'Start',
#   'title': 'Mulga, Alabama',
#   'lastrevid': 1157496931},
#  {'article': 'Munford, Alabama',
#   'prediction': 'C',
#   'title': 'Munford, Alabama',
#   'lastrevid': 1178871326},
#  {'article': 'Muscle Shoals, Alabama',
#   'prediction': 'C',
#   'title': 'Muscle Shoals, Alabama',
#   'lastrevid': 1178909921},
#  {'article': 'Myrtlewood, Alabama',
#   'prediction': 'GA',
#   'title': 'Myrtlewood, Alabama',
#   'lastrevid': 1166208882},
#  {'article': 'Napier Field, Alabama',
#   'prediction': 'Start',
#   'title': 'Napier Field, Alabama',
#   'lastrevid': 1166208894},
#  {'article': 'Natural Bridge, Alabama',
#   'prediction': 'C',
#   'title': 'Natural Bridge, Alabama',
#   'lastrevid': 1166208941},
#  {'article': 'Nauvoo, Alabama',
#   'prediction': 'C',
#   'title': 'Nauvoo, Alabama',
#   'lastrevid': 1096820857},
#  {'article': 'Nectar, Alabama',
#   'prediction': 'Start',
#   'title': 'Nectar, Alabama',
#   'lastrevid': 1166208963},
#  {'article': 'Needham, Alabama',
#   'prediction': 'Start',
#   'title': 'Needham, Alabama',
#   'lastrevid': 1166208968},
#  {'article': 'New Brockton, Alabama',
#   'prediction': 'C',
#   'title': 'New Brockton, Alabama',
#   'lastrevid': 1166209021},
#  {'article': 'New Hope, Alabama',
#   'prediction': 'C',
#   'title': 'New Hope, Alabama',
#   'lastrevid': 1179883996},
#  {'article': 'New Site, Alabama',
#   'prediction': 'Start',
#   'title': 'New Site, Alabama',
#   'lastrevid': 1166209336},
#  {'article': 'Newbern, Alabama',
#   'prediction': 'GA',
#   'title': 'Newbern, Alabama',
#   'lastrevid': 1176337691},
#  {'article': 'Newton, Alabama',
#   'prediction': 'C',
#   'title': 'Newton, Alabama',
#   'lastrevid': 1166209571},
#  {'article': 'Newville, Alabama',
#   'prediction': 'C',
#   'title': 'Newville, Alabama',
#   'lastrevid': 1177928995},
#  {'article': 'North Courtland, Alabama',
#   'prediction': 'Start',
#   'title': 'North Courtland, Alabama',
#   'lastrevid': 1166209704},
#  {'article': 'North Johns, Alabama',
#   'prediction': 'Start',
#   'title': 'North Johns, Alabama',
#   'lastrevid': 1166209738},
#  {'article': 'Northport, Alabama',
#   'prediction': 'C',
#   'title': 'Northport, Alabama',
#   'lastrevid': 1167817987},
#  {'article': 'Notasulga, Alabama',
#   'prediction': 'C',
#   'title': 'Notasulga, Alabama',
#   'lastrevid': 1175854552},
#  {'article': 'Oak Grove, Alabama',
#   'prediction': 'C',
#   'title': 'Oak Grove, Alabama',
#   'lastrevid': 1124809704},
#  {'article': 'Oak Hill, Alabama',
#   'prediction': 'C',
#   'title': 'Oak Hill, Alabama',
#   'lastrevid': 1166209958},
#  {'article': 'Oakman, Alabama',
#   'prediction': 'Start',
#   'title': 'Oakman, Alabama',
#   'lastrevid': 1174954255},
#  {'article': 'Odenville, Alabama',
#   'prediction': 'C',
#   'title': 'Odenville, Alabama',
#   'lastrevid': 1166210198},
#  {'article': 'Ohatchee, Alabama',
#   'prediction': 'C',
#   'title': 'Ohatchee, Alabama',
#   'lastrevid': 1166210252},
#  {'article': 'Oneonta, Alabama',
#   'prediction': 'C',
#   'title': 'Oneonta, Alabama',
#   'lastrevid': 1166092446},
#  {'article': 'Onycha, Alabama',
#   'prediction': 'Start',
#   'title': 'Onycha, Alabama',
#   'lastrevid': 1166210466},
#  {'article': 'Opelika, Alabama',
#   'prediction': 'C',
#   'title': 'Opelika, Alabama',
#   'lastrevid': 1165896665},
#  {'article': 'Opp, Alabama',
#   'prediction': 'C',
#   'title': 'Opp, Alabama',
#   'lastrevid': 1165896683},
#  {'article': 'Orange Beach, Alabama',
#   'prediction': 'C',
#   'title': 'Orange Beach, Alabama',
#   'lastrevid': 1179725369},
#  {'article': 'Orrville, Alabama',
#   'prediction': 'C',
#   'title': 'Orrville, Alabama',
#   'lastrevid': 1175606582},
#  {'article': 'Owens Cross Roads, Alabama',
#   'prediction': 'C',
#   'title': 'Owens Cross Roads, Alabama',
#   'lastrevid': 1172849762},
#  {'article': 'Oxford, Alabama',
#   'prediction': 'C',
#   'title': 'Oxford, Alabama',
#   'lastrevid': 1165896955},
#  {'article': 'Ozark, Alabama',
#   'prediction': 'C',
#   'title': 'Ozark, Alabama',
#   'lastrevid': 1175658038},
#  {'article': 'Paint Rock, Alabama',
#   'prediction': 'C',
#   'title': 'Paint Rock, Alabama',
#   'lastrevid': 1166210847},
#  {'article': 'Parrish, Alabama',
#   'prediction': 'C',
#   'title': 'Parrish, Alabama',
#   'lastrevid': 1166210982},
#  {'article': 'Pelham, Alabama',
#   'prediction': 'C',
#   'title': 'Pelham, Alabama',
#   'lastrevid': 1174024956},
#  {'article': 'Pell City, Alabama',
#   'prediction': 'C',
#   'title': 'Pell City, Alabama',
#   'lastrevid': 1171029165},
#  {'article': 'Pennington, Alabama',
#   'prediction': 'C',
#   'title': 'Pennington, Alabama',
#   'lastrevid': 1135170013},
#  {'article': 'Perdido Beach, Alabama',
#   'prediction': 'Start',
#   'title': 'Perdido Beach, Alabama',
#   'lastrevid': 1166211174},
#  {'article': 'Petrey, Alabama',
#   'prediction': 'C',
#   'title': 'Petrey, Alabama',
#   'lastrevid': 1096817791},
#  {'article': 'Phenix City, Alabama',
#   'prediction': 'C',
#   'title': 'Phenix City, Alabama',
#   'lastrevid': 1160284984},
#  {'article': 'Phil Campbell, Alabama',
#   'prediction': 'C',
#   'title': 'Phil Campbell, Alabama',
#   'lastrevid': 1176609767},
#  {'article': 'Pickensville, Alabama',
#   'prediction': 'C',
#   'title': 'Pickensville, Alabama',
#   'lastrevid': 1166211277},
#  {'article': 'Piedmont, Alabama',
#   'prediction': 'C',
#   'title': 'Piedmont, Alabama',
#   'lastrevid': 1174026676},
#  {'article': 'Pike Road, Alabama',
#   'prediction': 'C',
#   'title': 'Pike Road, Alabama',
#   'lastrevid': 1170574167},
#  {'article': 'Pinckard, Alabama',
#   'prediction': 'Start',
#   'title': 'Pinckard, Alabama',
#   'lastrevid': 1166211323},
#  {'article': 'Pine Apple, Alabama',
#   'prediction': 'C',
#   'title': 'Pine Apple, Alabama',
#   'lastrevid': 1166211355},
#  {'article': 'Pine Hill, Alabama',
#   'prediction': 'Start',
#   'title': 'Pine Hill, Alabama',
#   'lastrevid': 1166211367},
#  {'article': 'Pine Ridge, Alabama',
#   'prediction': 'Start',
#   'title': 'Pine Ridge, Alabama',
#   'lastrevid': 1166211388},
#  {'article': 'Pinson, Alabama',
#   'prediction': 'C',
#   'title': 'Pinson, Alabama',
#   'lastrevid': 1178582292},
#  {'article': 'Pisgah, Alabama',
#   'prediction': 'C',
#   'title': 'Pisgah, Alabama',
#   'lastrevid': 1166211442},
#  {'article': 'Pleasant Grove, Alabama',
#   'prediction': 'C',
#   'title': 'Pleasant Grove, Alabama',
#   'lastrevid': 1177636010},
#  {'article': 'Pleasant Groves, Alabama',
#   'prediction': 'Start',
#   'title': 'Pleasant Groves, Alabama',
#   'lastrevid': 1166229073},
#  {'article': 'Pollard, Alabama',
#   'prediction': 'Start',
#   'title': 'Pollard, Alabama',
#   'lastrevid': 1166229176},
#  {'article': 'Powell, Alabama',
#   'prediction': 'C',
#   'title': 'Powell, Alabama',
#   'lastrevid': 1166229333},
#  {'article': 'Prattville, Alabama',
#   'prediction': 'C',
#   'title': 'Prattville, Alabama',
#   'lastrevid': 1167939343},
#  {'article': 'Priceville, Alabama',
#   'prediction': 'C',
#   'title': 'Priceville, Alabama',
#   'lastrevid': 1166229409},
#  {'article': 'Prichard, Alabama',
#   'prediction': 'C',
#   'title': 'Prichard, Alabama',
#   'lastrevid': 1176865405},
#  {'article': 'Providence, Alabama',
#   'prediction': 'Start',
#   'title': 'Providence, Alabama',
#   'lastrevid': 1166229472},
#  {'article': 'Ragland, Alabama',
#   'prediction': 'C',
#   'title': 'Ragland, Alabama',
#   'lastrevid': 1166229540},
#  {'article': 'Rainbow City, Alabama',
#   'prediction': 'GA',
#   'title': 'Rainbow City, Alabama',
#   'lastrevid': 1158827266},
#  {'article': 'Rainsville, Alabama',
#   'prediction': 'C',
#   'title': 'Rainsville, Alabama',
#   'lastrevid': 1171084402},
#  {'article': 'Ranburne, Alabama',
#   'prediction': 'C',
#   'title': 'Ranburne, Alabama',
#   'lastrevid': 1166229569},
#  {'article': 'Red Bay, Alabama',
#   'prediction': 'C',
#   'title': 'Red Bay, Alabama',
#   'lastrevid': 1169333757},
#  {'article': 'Red Level, Alabama',
#   'prediction': 'C',
#   'title': 'Red Level, Alabama',
#   'lastrevid': 1166229671},
#  {'article': 'Reece City, Alabama',
#   'prediction': 'Start',
#   'title': 'Reece City, Alabama',
#   'lastrevid': 1166229699},
#  {'article': 'Reform, Alabama',
#   'prediction': 'C',
#   'title': 'Reform, Alabama',
#   'lastrevid': 1165899409},
#  {'article': 'Rehobeth, Alabama',
#   'prediction': 'C',
#   'title': 'Rehobeth, Alabama',
#   'lastrevid': 1172196089},
#  {'article': 'Repton, Alabama',
#   'prediction': 'Start',
#   'title': 'Repton, Alabama',
#   'lastrevid': 1166229759},
#  {'article': 'Ridgeville, Alabama',
#   'prediction': 'Start',
#   'title': 'Ridgeville, Alabama',
#   'lastrevid': 1166229906},
#  {'article': 'River Falls, Alabama',
#   'prediction': 'C',
#   'title': 'River Falls, Alabama',
#   'lastrevid': 1166230019},
#  {'article': 'Riverside, Alabama',
#   'prediction': 'C',
#   'title': 'Riverside, Alabama',
#   'lastrevid': 1166230024},
#  {'article': 'Riverview, Alabama',
#   'prediction': 'Start',
#   'title': 'Riverview, Alabama',
#   'lastrevid': 1166230040},
#  {'article': 'Roanoke, Alabama',
#   'prediction': 'C',
#   'title': 'Roanoke, Alabama',
#   'lastrevid': 1165899878},
#  {'article': 'Robertsdale, Alabama',
#   'prediction': 'C',
#   'title': 'Robertsdale, Alabama',
#   'lastrevid': 1166314424},
#  {'article': 'Rockford, Alabama',
#   'prediction': 'GA',
#   'title': 'Rockford, Alabama',
#   'lastrevid': 1169199856},
#  {'article': 'Rogersville, Alabama',
#   'prediction': 'C',
#   'title': 'Rogersville, Alabama',
#   'lastrevid': 1166230187},
#  {'article': 'Rosa, Alabama',
#   'prediction': 'Start',
#   'title': 'Rosa, Alabama',
#   'lastrevid': 1166230264},
#  {'article': 'Russellville, Alabama',
#   'prediction': 'GA',
#   'title': 'Russellville, Alabama',
#   'lastrevid': 1165900503},
#  {'article': 'Rutledge, Alabama',
#   'prediction': 'Start',
#   'title': 'Rutledge, Alabama',
#   'lastrevid': 1166230534},
#  {'article': 'St. Florian, Alabama',
#   'prediction': 'C',
#   'title': 'St. Florian, Alabama',
#   'lastrevid': 1166330128},
#  {'article': 'Samson, Alabama',
#   'prediction': 'C',
#   'title': 'Samson, Alabama',
#   'lastrevid': 1165900688},
#  {'article': 'Sand Rock, Alabama',
#   'prediction': 'C',
#   'title': 'Sand Rock, Alabama',
#   'lastrevid': 1166230657},
#  {'article': 'Sanford, Alabama',
#   'prediction': 'Start',
#   'title': 'Sanford, Alabama',
#   'lastrevid': 1166230687},
#  {'article': 'Saraland, Alabama',
#   'prediction': 'GA',
#   'title': 'Saraland, Alabama',
#   'lastrevid': 1176013392},
#  {'article': 'Sardis City, Alabama',
#   'prediction': 'C',
#   'title': 'Sardis City, Alabama',
#   'lastrevid': 1166230721},
#  {'article': 'Satsuma, Alabama',
#   'prediction': 'C',
#   'title': 'Satsuma, Alabama',
#   'lastrevid': 1165900914},
#  {'article': 'Scottsboro, Alabama',
#   'prediction': 'C',
#   'title': 'Scottsboro, Alabama',
#   'lastrevid': 1174635424},
#  {'article': 'Section, Alabama',
#   'prediction': 'C',
#   'title': 'Section, Alabama',
#   'lastrevid': 1166230919},
#  {'article': 'Selma, Alabama',
#   'prediction': 'C',
#   'title': 'Selma, Alabama',
#   'lastrevid': 1143473983},
#  {'article': 'Sheffield, Alabama',
#   'prediction': 'C',
#   'title': 'Sheffield, Alabama',
#   'lastrevid': 1178910007},
#  {'article': 'Shiloh, DeKalb County, Alabama',
#   'prediction': 'C',
#   'title': 'Shiloh, DeKalb County, Alabama',
#   'lastrevid': 1166231236},
#  {'article': 'Shorter, Alabama',
#   'prediction': 'C',
#   'title': 'Shorter, Alabama',
#   'lastrevid': 1167174337},
#  {'article': 'Silas, Alabama',
#   'prediction': 'C',
#   'title': 'Silas, Alabama',
#   'lastrevid': 1166231326},
#  {'article': 'Silverhill, Alabama',
#   'prediction': 'C',
#   'title': 'Silverhill, Alabama',
#   'lastrevid': 1178521390},
#  {'article': 'Sipsey, Alabama',
#   'prediction': 'Start',
#   'title': 'Sipsey, Alabama',
#   'lastrevid': 1166231394},
#  {'article': 'Skyline, Alabama',
#   'prediction': 'C',
#   'title': 'Skyline, Alabama',
#   'lastrevid': 1166231421},
#  {'article': 'Slocomb, Alabama',
#   'prediction': 'Start',
#   'title': 'Slocomb, Alabama',
#   'lastrevid': 1165901938},
#  {'article': 'Smiths Station, Alabama',
#   'prediction': 'C',
#   'title': 'Smiths Station, Alabama',
#   'lastrevid': 1165901985},
#  {'article': 'Snead, Alabama',
#   'prediction': 'Start',
#   'title': 'Snead, Alabama',
#   'lastrevid': 1166231481},
#  {'article': 'Somerville, Alabama',
#   'prediction': 'C',
#   'title': 'Somerville, Alabama',
#   'lastrevid': 1166231524},
#  {'article': 'South Vinemont, Alabama',
#   'prediction': 'Start',
#   'title': 'South Vinemont, Alabama',
#   'lastrevid': 1166329815},
#  {'article': 'Southside, Alabama',
#   'prediction': 'C',
#   'title': 'Southside, Alabama',
#   'lastrevid': 1165902345},
#  {'article': 'Spanish Fort, Alabama',
#   'prediction': 'C',
#   'title': 'Spanish Fort, Alabama',
#   'lastrevid': 1178909983},
#  {'article': 'Springville, Alabama',
#   'prediction': 'C',
#   'title': 'Springville, Alabama',
#   'lastrevid': 1165902747},
#  {'article': 'Steele, Alabama',
#   'prediction': 'C',
#   'title': 'Steele, Alabama',
#   'lastrevid': 1166330411},
#  {'article': 'Stevenson, Alabama',
#   'prediction': 'C',
#   'title': 'Stevenson, Alabama',
#   'lastrevid': 1165903151},
#  {'article': 'Sulligent, Alabama',
#   'prediction': 'C',
#   'title': 'Sulligent, Alabama',
#   'lastrevid': 1165903367},
#  {'article': 'Sumiton, Alabama',
#   'prediction': 'C',
#   'title': 'Sumiton, Alabama',
#   'lastrevid': 1177623469},
#  {'article': 'Summerdale, Alabama',
#   'prediction': 'C',
#   'title': 'Summerdale, Alabama',
#   'lastrevid': 1166330782},
#  {'article': 'Susan Moore, Alabama',
#   'prediction': 'C',
#   'title': 'Susan Moore, Alabama',
#   'lastrevid': 1166330933},
#  {'article': 'Sweet Water, Alabama',
#   'prediction': 'GA',
#   'title': 'Sweet Water, Alabama',
#   'lastrevid': 1170589664},
#  {'article': 'Sylacauga, Alabama',
#   'prediction': 'C',
#   'title': 'Sylacauga, Alabama',
#   'lastrevid': 1176796677},
#  {'article': 'Sylvan Springs, Alabama',
#   'prediction': 'Start',
#   'title': 'Sylvan Springs, Alabama',
#   'lastrevid': 1177624259},
#  {'article': 'Sylvania, Alabama',
#   'prediction': 'GA',
#   'title': 'Sylvania, Alabama',
#   'lastrevid': 1166331023},
#  {'article': 'Talladega Springs, Alabama',
#   'prediction': 'C',
#   'title': 'Talladega Springs, Alabama',
#   'lastrevid': 1166331095},
#  {'article': 'Talladega, Alabama',
#   'prediction': 'C',
#   'title': 'Talladega, Alabama',
#   'lastrevid': 1165903654},
#  {'article': 'Tallassee, Alabama',
#   'prediction': 'C',
#   'title': 'Tallassee, Alabama',
#   'lastrevid': 1151228134},
#  {'article': 'Tarrant, Alabama',
#   'prediction': 'C',
#   'title': 'Tarrant, Alabama',
#   'lastrevid': 1177783643},
#  {'article': 'Taylor, Alabama',
# ...
#   'title': 'Fountain Hill, Arkansas',
#   'lastrevid': 1166068542},
#  {'article': 'Fountain Lake, Arkansas',
#   'prediction': 'GA',
#   'title': 'Fountain Lake, Arkansas',
#   'lastrevid': 1165747278},
#  {'article': 'Fourche, Arkansas',
#   'prediction': 'Start',
#   'title': 'Fourche, Arkansas',
#   'lastrevid': 1166068550},
#  {'article': 'Franklin, Arkansas',
#   'prediction': 'Start',
#   'title': 'Franklin, Arkansas',
#   'lastrevid': 1166068624},
#  {'article': 'Fredonia (Biscoe), Arkansas',
#   'prediction': 'Start',
#   'title': 'Fredonia (Biscoe), Arkansas',
#   'lastrevid': 1165747381},
#  {'article': 'Friendship, Arkansas',
#   'prediction': 'GA',
#   'title': 'Friendship, Arkansas',
#   'lastrevid': 1166068832},
#  {'article': 'Fulton, Arkansas',
#   'prediction': 'C',
#   'title': 'Fulton, Arkansas',
#   'lastrevid': 1099557078},
#  {'article': 'Garfield, Arkansas',
#   'prediction': 'C',
#   'title': 'Garfield, Arkansas',
#   'lastrevid': 1166069011},
#  {'article': 'Garland, Arkansas',
#   'prediction': 'C',
#   'title': 'Garland, Arkansas',
#   'lastrevid': 1166069032},
#  {'article': 'Garner, Arkansas',
#   'prediction': 'Start',
#   'title': 'Garner, Arkansas',
#   'lastrevid': 1166069049},
#  {'article': 'Gassville, Arkansas',
#   'prediction': 'C',
#   'title': 'Gassville, Arkansas',
#   'lastrevid': 1165747767},
#  {'article': 'Gateway, Arkansas',
#   'prediction': 'C',
#   'title': 'Gateway, Arkansas',
#   'lastrevid': 1166069104},
#  {'article': 'Gentry, Arkansas',
#   'prediction': 'C',
#   'title': 'Gentry, Arkansas',
#   'lastrevid': 1165747839},
#  {'article': 'Georgetown, Arkansas',
#   'prediction': 'Start',
#   'title': 'Georgetown, Arkansas',
#   'lastrevid': 1166069157},
#  {'article': 'Gilbert, Arkansas',
#   'prediction': 'C',
#   'title': 'Gilbert, Arkansas',
#   'lastrevid': 1166069402},
#  {'article': 'Gillett, Arkansas',
#   'prediction': 'C',
#   'title': 'Gillett, Arkansas',
#   'lastrevid': 1165747967},
#  {'article': 'Gillham, Arkansas',
#   'prediction': 'Start',
#   'title': 'Gillham, Arkansas',
#   'lastrevid': 1166069425},
#  {'article': 'Gilmore, Arkansas',
#   'prediction': 'GA',
#   'title': 'Gilmore, Arkansas',
#   'lastrevid': 1152406083},
#  {'article': 'Glenwood, Arkansas',
#   'prediction': 'GA',
#   'title': 'Glenwood, Arkansas',
#   'lastrevid': 1165748120},
#  {'article': 'Goshen, Arkansas',
#   'prediction': 'C',
#   'title': 'Goshen, Arkansas',
#   'lastrevid': 1177678339},
#  {'article': 'Gosnell, Arkansas',
#   'prediction': 'C',
#   'title': 'Gosnell, Arkansas',
#   'lastrevid': 1165748275},
#  {'article': 'Gould, Arkansas',
#   'prediction': 'GA',
#   'title': 'Gould, Arkansas',
#   'lastrevid': 1178972383},
#  {'article': 'Grady, Arkansas',
#   'prediction': 'C',
#   'title': 'Grady, Arkansas',
#   'lastrevid': 1178974249},
#  {'article': 'Grannis, Arkansas',
#   'prediction': 'C',
#   'title': 'Grannis, Arkansas',
#   'lastrevid': 1165748512},
#  {'article': 'Gravette, Arkansas',
#   'prediction': 'GA',
#   'title': 'Gravette, Arkansas',
#   'lastrevid': 1176916498},
#  {'article': 'Green Forest, Arkansas',
#   'prediction': 'C',
#   'title': 'Green Forest, Arkansas',
#   'lastrevid': 1166318848},
#  {'article': 'Greenbrier, Arkansas',
#   'prediction': 'C',
#   'title': 'Greenbrier, Arkansas',
#   'lastrevid': 1166318561},
#  {'article': 'Greenland, Arkansas',
#   'prediction': 'C',
#   'title': 'Greenland, Arkansas',
#   'lastrevid': 1177678742},
#  {'article': 'Greenway, Arkansas',
#   'prediction': 'C',
#   'title': 'Greenway, Arkansas',
#   'lastrevid': 1165748770},
#  {'article': 'Greenwood, Arkansas',
#   'prediction': 'C',
#   'title': 'Greenwood, Arkansas',
#   'lastrevid': 1119890453},
#  {'article': 'Greers Ferry, Arkansas',
#   'prediction': 'Start',
#   'title': 'Greers Ferry, Arkansas',
#   'lastrevid': 1165748791},
#  {'article': 'Griffithville, Arkansas',
#   'prediction': 'Start',
#   'title': 'Griffithville, Arkansas',
#   'lastrevid': 1166180115},
#  {'article': 'Grubbs, Arkansas',
#   'prediction': 'Start',
#   'title': 'Grubbs, Arkansas',
#   'lastrevid': 1165748877},
#  {'article': 'Guion, Arkansas',
#   'prediction': 'GA',
#   'title': 'Guion, Arkansas',
#   'lastrevid': 1171834862},
#  {'article': 'Gum Springs, Arkansas',
#   'prediction': 'C',
#   'title': 'Gum Springs, Arkansas',
#   'lastrevid': 1166180237},
#  {'article': 'Gurdon, Arkansas',
#   'prediction': 'C',
#   'title': 'Gurdon, Arkansas',
#   'lastrevid': 1165748930},
#  {'article': 'Guy, Arkansas',
#   'prediction': 'GA',
#   'title': 'Guy, Arkansas',
#   'lastrevid': 1165748951},
#  {'article': 'Hackett, Arkansas',
#   'prediction': 'Start',
#   'title': 'Hackett, Arkansas',
#   'lastrevid': 1165748965},
#  {'article': 'Hamburg, Arkansas',
#   'prediction': 'C',
#   'title': 'Hamburg, Arkansas',
#   'lastrevid': 1165749058},
#  {'article': 'Hampton, Arkansas',
#   'prediction': 'C',
#   'title': 'Hampton, Arkansas',
#   'lastrevid': 1173804261},
#  {'article': 'Hardy, Arkansas',
#   'prediction': 'C',
#   'title': 'Hardy, Arkansas',
#   'lastrevid': 1165749222},
#  {'article': 'Harrell, Arkansas',
#   'prediction': 'Start',
#   'title': 'Harrell, Arkansas',
#   'lastrevid': 1166180539},
#  {'article': 'Harrisburg, Arkansas',
#   'prediction': 'Start',
#   'title': 'Harrisburg, Arkansas',
#   'lastrevid': 1176420942},
#  {'article': 'Harrison, Arkansas',
#   'prediction': 'C',
#   'title': 'Harrison, Arkansas',
#   'lastrevid': 1175371914},
#  {'article': 'Hartford, Arkansas',
#   'prediction': 'C',
#   'title': 'Hartford, Arkansas',
#   'lastrevid': 1165749309},
#  {'article': 'Hartman, Arkansas',
#   'prediction': 'C',
#   'title': 'Hartman, Arkansas',
#   'lastrevid': 1169860743},
#  {'article': 'Haskell, Arkansas',
#   'prediction': 'Start',
#   'title': 'Haskell, Arkansas',
#   'lastrevid': 1165749376},
#  {'article': 'Hatfield, Arkansas',
#   'prediction': 'C',
#   'title': 'Hatfield, Arkansas',
#   'lastrevid': 1177681806},
#  {'article': 'Havana, Arkansas',
#   'prediction': 'C',
#   'title': 'Havana, Arkansas',
#   'lastrevid': 1165749405},
#  {'article': 'Haynes, Arkansas',
#   'prediction': 'C',
#   'title': 'Haynes, Arkansas',
#   'lastrevid': 1166180758},
#  {'article': 'Hazen, Arkansas',
#   'prediction': 'C',
#   'title': 'Hazen, Arkansas',
#   'lastrevid': 1176800150},
#  {'article': 'Heber Springs, Arkansas',
#   'prediction': 'C',
#   'title': 'Heber Springs, Arkansas',
#   'lastrevid': 1165749637},
#  {'article': 'Hector, Arkansas',
#   'prediction': 'C',
#   'title': 'Hector, Arkansas',
#   'lastrevid': 1166180833},
#  {'article': 'Helena-West Helena, Arkansas',
#   'prediction': 'Stub',
#   'title': 'Helena-West Helena, Arkansas',
#   'lastrevid': 772867043},
#  {'article': 'Hermitage, Arkansas',
#   'prediction': 'C',
#   'title': 'Hermitage, Arkansas',
#   'lastrevid': 1165749806},
#  {'article': 'Hickory Ridge, Arkansas',
#   'prediction': 'C',
#   'title': 'Hickory Ridge, Arkansas',
#   'lastrevid': 1165749900},
#  {'article': 'Higden, Arkansas',
#   'prediction': 'C',
#   'title': 'Higden, Arkansas',
#   'lastrevid': 1166180970},
#  {'article': 'Higginson, Arkansas',
#   'prediction': 'C',
#   'title': 'Higginson, Arkansas',
#   'lastrevid': 1165749951},
#  {'article': 'Highfill, Arkansas',
#   'prediction': 'GA',
#   'title': 'Highfill, Arkansas',
#   'lastrevid': 1176219624},
#  {'article': 'Highland, Arkansas',
#   'prediction': 'Start',
#   'title': 'Highland, Arkansas',
#   'lastrevid': 1165749996},
#  {'article': 'Hindsville, Arkansas',
#   'prediction': 'GA',
#   'title': 'Hindsville, Arkansas',
#   'lastrevid': 1166181098},
#  {'article': 'Holland, Arkansas',
#   'prediction': 'C',
#   'title': 'Holland, Arkansas',
#   'lastrevid': 1165750207},
#  {'article': 'Holly Grove, Arkansas',
#   'prediction': 'C',
#   'title': 'Holly Grove, Arkansas',
#   'lastrevid': 1165750244},
#  {'article': 'Hope, Arkansas',
#   'prediction': 'C',
#   'title': 'Hope, Arkansas',
#   'lastrevid': 1171539875},
#  {'article': 'Horatio, Arkansas',
#   'prediction': 'Start',
#   'title': 'Horatio, Arkansas',
#   'lastrevid': 1177682191},
#  {'article': 'Horseshoe Bend, Arkansas',
#   'prediction': 'C',
#   'title': 'Horseshoe Bend, Arkansas',
#   'lastrevid': 1165750423},
#  {'article': 'Horseshoe Lake, Arkansas',
#   'prediction': 'C',
#   'title': 'Horseshoe Lake, Arkansas',
#   'lastrevid': 1166181414},
#  {'article': 'Hot Springs, Arkansas',
#   'prediction': 'B',
#   'title': 'Hot Springs, Arkansas',
#   'lastrevid': 1178629718},
#  {'article': 'Houston, Arkansas',
#   'prediction': 'Start',
#   'title': 'Houston, Arkansas',
#   'lastrevid': 1166181431},
#  {'article': 'Hoxie, Arkansas',
#   'prediction': 'GA',
#   'title': 'Hoxie, Arkansas',
#   'lastrevid': 1154007587},
#  {'article': 'Hughes, Arkansas',
#   'prediction': 'GA',
#   'title': 'Hughes, Arkansas',
#   'lastrevid': 1165750560},
#  {'article': 'Humnoke, Arkansas',
#   'prediction': 'C',
#   'title': 'Humnoke, Arkansas',
#   'lastrevid': 1165750602},
#  {'article': 'Humphrey, Arkansas',
#   'prediction': 'Start',
#   'title': 'Humphrey, Arkansas',
#   'lastrevid': 1165750603},
#  {'article': 'Hunter, Arkansas',
#   'prediction': 'Start',
#   'title': 'Hunter, Arkansas',
#   'lastrevid': 1166181533},
#  {'article': 'Huntington, Arkansas',
#   'prediction': 'Start',
#   'title': 'Huntington, Arkansas',
#   'lastrevid': 1165750630},
#  {'article': 'Huntsville, Arkansas',
#   'prediction': 'C',
#   'title': 'Huntsville, Arkansas',
#   'lastrevid': 1165750652},
#  {'article': 'Huttig, Arkansas',
#   'prediction': 'Start',
#   'title': 'Huttig, Arkansas',
#   'lastrevid': 1165750708},
#  {'article': 'Imboden, Arkansas',
#   'prediction': 'C',
#   'title': 'Imboden, Arkansas',
#   'lastrevid': 1165750775},
#  {'article': 'Jacksonport, Arkansas',
#   'prediction': 'C',
#   'title': 'Jacksonport, Arkansas',
#   'lastrevid': 1166181828},
#  {'article': 'Jacksonville, Arkansas',
#   'prediction': 'C',
#   'title': 'Jacksonville, Arkansas',
#   'lastrevid': 1176249122},
#  {'article': 'Jasper, Arkansas',
#   'prediction': 'C',
#   'title': 'Jasper, Arkansas',
#   'lastrevid': 1165751077},
#  {'article': 'Jennette, Arkansas',
#   'prediction': 'C',
#   'title': 'Jennette, Arkansas',
#   'lastrevid': 1166181989},
#  {'article': 'Jericho, Arkansas',
#   'prediction': 'C',
#   'title': 'Jericho, Arkansas',
#   'lastrevid': 1166182002},
#  {'article': 'Johnson, Arkansas',
#   'prediction': 'C',
#   'title': 'Johnson, Arkansas',
#   'lastrevid': 1177679078},
#  {'article': 'Joiner, Arkansas',
#   'prediction': 'C',
#   'title': 'Joiner, Arkansas',
#   'lastrevid': 1165751252},
#  {'article': 'Jonesboro, Arkansas',
#   'prediction': 'C',
#   'title': 'Jonesboro, Arkansas',
#   'lastrevid': 1174828145},
#  {'article': 'Judsonia, Arkansas',
#   'prediction': 'C',
#   'title': 'Judsonia, Arkansas',
#   'lastrevid': 1156602906},
#  {'article': 'Junction City, Arkansas',
#   'prediction': 'Start',
#   'title': 'Junction City, Arkansas',
#   'lastrevid': 1165751393},
#  {'article': 'Keiser, Arkansas',
#   'prediction': 'GA',
#   'title': 'Keiser, Arkansas',
#   'lastrevid': 1165751940},
#  {'article': 'Kensett, Arkansas',
#   'prediction': 'C',
#   'title': 'Kensett, Arkansas',
#   'lastrevid': 1165752036},
#  {'article': 'Keo, Arkansas',
#   'prediction': 'GA',
#   'title': 'Keo, Arkansas',
#   'lastrevid': 1166182306},
#  {'article': 'Kibler, Arkansas',
#   'prediction': 'Start',
#   'title': 'Kibler, Arkansas',
#   'lastrevid': 1165752160},
#  {'article': 'Kingsland, Arkansas',
#   'prediction': 'C',
#   'title': 'Kingsland, Arkansas',
#   'lastrevid': 1165752244},
#  {'article': 'Knobel, Arkansas',
#   'prediction': 'C',
#   'title': 'Knobel, Arkansas',
#   'lastrevid': 1165752352},
#  {'article': 'Knoxville, Arkansas',
#   'prediction': 'Start',
#   'title': 'Knoxville, Arkansas',
#   'lastrevid': 1147573042},
#  {'article': 'Lafe, Arkansas',
#   'prediction': 'C',
#   'title': 'Lafe, Arkansas',
#   'lastrevid': 1159615350},
#  {'article': 'LaGrange, Arkansas',
#   'prediction': 'C',
#   'title': 'LaGrange, Arkansas',
#   'lastrevid': 1166182719},
#  {'article': 'Lake City, Arkansas',
#   'prediction': 'C',
#   'title': 'Lake City, Arkansas',
#   'lastrevid': 1165752677},
#  {'article': 'Lake View, Arkansas',
#   'prediction': 'C',
#   'title': 'Lake View, Arkansas',
#   'lastrevid': 1165752788},
#  {'article': 'Lake Village, Arkansas',
#   'prediction': 'C',
#   'title': 'Lake Village, Arkansas',
#   'lastrevid': 1165752790},
#  {'article': 'Lakeview, Arkansas',
#   'prediction': 'Start',
#   'title': 'Lakeview, Arkansas',
#   'lastrevid': 1175835411},
#  {'article': 'Lamar, Arkansas',
#   'prediction': 'C',
#   'title': 'Lamar, Arkansas',
#   'lastrevid': 1147572638},
#  {'article': 'Lavaca, Arkansas',
#   'prediction': 'Start',
#   'title': 'Lavaca, Arkansas',
#   'lastrevid': 1165889406},
#  {'article': 'Leachville, Arkansas',
#   'prediction': 'C',
#   'title': 'Leachville, Arkansas',
#   'lastrevid': 1170904211},
#  {'article': 'Lead Hill, Arkansas',
#   'prediction': 'C',
#   'title': 'Lead Hill, Arkansas',
#   'lastrevid': 1166205650},
#  {'article': 'Leola, Arkansas',
#   'prediction': 'C',
#   'title': 'Leola, Arkansas',
#   'lastrevid': 1165889943},
#  {'article': 'Lepanto, Arkansas',
#   'prediction': 'C',
#   'title': 'Lepanto, Arkansas',
#   'lastrevid': 1165890009},
#  {'article': 'Leslie, Arkansas',
#   'prediction': 'C',
#   'title': 'Leslie, Arkansas',
#   'lastrevid': 1165890025},
#  {'article': 'Letona, Arkansas',
#   'prediction': 'Start',
#   'title': 'Letona, Arkansas',
#   'lastrevid': 1166205839},
#  {'article': 'Lewisville, Arkansas',
#   'prediction': 'C',
#   'title': 'Lewisville, Arkansas',
#   'lastrevid': 1165890098},
#  {'article': 'Lexa, Arkansas',
#   'prediction': 'C',
#   'title': 'Lexa, Arkansas',
#   'lastrevid': 1166205876},
#  {'article': 'Lincoln, Arkansas',
#   'prediction': 'C',
#   'title': 'Lincoln, Arkansas',
#   'lastrevid': 1177679163},
#  {'article': 'Little Flock, Arkansas',
#   'prediction': 'C',
#   'title': 'Little Flock, Arkansas',
#   'lastrevid': 1165891079},
#  {'article': 'Little Rock, Arkansas',
#   'prediction': 'C',
#   'title': 'Little Rock, Arkansas',
#   'lastrevid': 1178670970},
#  {'article': 'Lockesburg, Arkansas',
#   'prediction': 'GA',
#   'title': 'Lockesburg, Arkansas',
#   'lastrevid': 1166660192},
#  {'article': 'London, Arkansas',
#   'prediction': 'C',
#   'title': 'London, Arkansas',
#   'lastrevid': 1165891215},
#  {'article': 'Lonoke, Arkansas',
#   'prediction': 'C',
#   'title': 'Lonoke, Arkansas',
#   'lastrevid': 1159321714},
#  {'article': 'Lonsdale, Arkansas',
#   'prediction': 'C',
#   'title': 'Lonsdale, Arkansas',
#   'lastrevid': 1166206287},
#  {'article': 'Louann, Arkansas',
#   'prediction': 'Start',
#   'title': 'Louann, Arkansas',
#   'lastrevid': 1166206314},
#  {'article': 'Lowell, Arkansas',
#   'prediction': 'C',
#   'title': 'Lowell, Arkansas',
#   'lastrevid': 1168694087},
#  {'article': 'Luxora, Arkansas',
#   'prediction': 'C',
#   'title': 'Luxora, Arkansas',
#   'lastrevid': 1165891647},
#  {'article': 'Lynn, Arkansas',
#   'prediction': 'C',
#   'title': 'Lynn, Arkansas',
#   'lastrevid': 1166206563},
#  {'article': 'Madison, Arkansas',
#   'prediction': 'C',
#   'title': 'Madison, Arkansas',
#   'lastrevid': 1165891768},
#  {'article': 'Magazine, Arkansas',
#   'prediction': 'Start',
#   'title': 'Magazine, Arkansas',
#   'lastrevid': 1165891808},
#  {'article': 'Magness, Arkansas',
#   'prediction': 'C',
#   'title': 'Magness, Arkansas',
#   'lastrevid': 1166206651},
#  {'article': 'Magnolia, Arkansas',
#   'prediction': 'C',
#   'title': 'Magnolia, Arkansas',
#   'lastrevid': 1176432893},
#  {'article': 'Malvern, Arkansas',
#   'prediction': 'C',
#   'title': 'Malvern, Arkansas',
#   'lastrevid': 1166966960},
#  {'article': 'Mammoth Spring, Arkansas',
#   'prediction': 'C',
#   'title': 'Mammoth Spring, Arkansas',
#   'lastrevid': 1171531945},
#  {'article': 'Manila, Arkansas',
#   'prediction': 'GA',
#   'title': 'Manila, Arkansas',
#   'lastrevid': 1165891972},
#  {'article': 'Mansfield, Arkansas',
#   'prediction': 'C',
#   'title': 'Mansfield, Arkansas',
#   'lastrevid': 1165892019},
#  {'article': 'Marianna, Arkansas',
#   'prediction': 'C',
#   'title': 'Marianna, Arkansas',
#   'lastrevid': 1165892179},
#  {'article': 'Marie, Arkansas',
#   'prediction': 'C',
#   'title': 'Marie, Arkansas',
#   'lastrevid': 1166206882},
#  {'article': 'Marion, Arkansas',
#   'prediction': 'GA',
#   'title': 'Marion, Arkansas',
#   'lastrevid': 1168263196},
#  {'article': 'Marked Tree, Arkansas',
#   'prediction': 'C',
#   'title': 'Marked Tree, Arkansas',
#   'lastrevid': 1165892278},
#  {'article': 'Marmaduke, Arkansas',
#   'prediction': 'C',
#   'title': 'Marmaduke, Arkansas',
#   'lastrevid': 1166678403},
#  {'article': 'Marshall, Arkansas',
#   'prediction': 'C',
#   'title': 'Marshall, Arkansas',
#   'lastrevid': 1177291499},
#  ...]

# %% [markdown]
# We want the 'state' as a seperate key-value pair in our dict as this has been outlined in the homework document.

# %%
# Add the 'state' key-value pair
for item in title_revid_list:
    title = item.get('title', '')
    state = title.split(', ')[-1]
    item['state'] = state
print(title_revid_list)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Now we will read the population data into a dataframe. The US Census Bureau provides updated population estimates for every US state. The data can be found on ['State Population Totals and Components of Change: 2020-2022'](https://www.census.gov/data/tables/time-series/demo/popest/2020s-state-total.html) from their website. An Excel file linked to that page contains estimated populations of all US states for 2022. - https://www.census.gov/data/tables/time-series/demo/popest/2020s-state-total.html
# I have uploaded the file to my drive and hence am accessing it from there.

# %%
population_data = pd.read_excel('/content/drive/My Drive/NST-EST2022-POP.xlsx')
population_data
# Out:
#    table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)  \
# 0                                     Geographic Area
# 1                                                 NaN
# 2                                       United States
# 3                                           Northeast
# 4                                             Midwest
# ..                                                ...
# 60  Note: The estimates are developed from a base ...
# 61                                Suggested Citation:
# 62  Annual Estimates of the Resident Population fo...
# 63    Source: U.S. Census Bureau, Population Division
# 64                        Release Date: December 2022
#
#                       Unnamed: 1                          Unnamed: 2  \
# 0   April 1, 2020 Estimates Base  Population Estimate (as of July 1)
# 1                            NaN                                2020
# 2                      331449520                           331511512
# 3                       57609156                            57448898
# 4                       68985537                            68961043
# ..                           ...                                 ...
# 60                           NaN                                 NaN
# 61                           NaN                                 NaN
# 62                           NaN                                 NaN
# 63                           NaN                                 NaN
# 64                           NaN                                 NaN
#
#      Unnamed: 3   Unnamed: 4
# 0           NaN          NaN
# 1        2021.0       2022.0
# 2   332031554.0  333287557.0
# 3    57259257.0   57040406.0
# 4    68836505.0   68787595.0
# ..          ...          ...
# 60          NaN          NaN
# 61          NaN          NaN
# 62          NaN          NaN
# 63          NaN          NaN
# 64          NaN          NaN
#
# [65 rows x 5 columns]

# %% [markdown]
# Pre-processing the population data

# %%
# Set the first row as column names and remove the existing columns
population_data.columns = population_data.iloc[0]
population_data = population_data[1:]

# Reset the index
population_data.reset_index(drop=True, inplace=True)
#Picking 2 columns which are needed for our analysis out of the whole dataset
population_data = population_data[['Geographic Area',population_data.columns[-1]]]
population_data.drop(0)
# Out:
# 0                                     Geographic Area          NaN
# 1                                       United States  333287557.0
# 2                                           Northeast   57040406.0
# 3                                             Midwest   68787595.0
# 4                                               South  128716192.0
# 5                                                West   78743364.0
# ..                                                ...          ...
# 59  Note: The estimates are developed from a base ...          NaN
# 60                                Suggested Citation:          NaN
# 61  Annual Estimates of the Resident Population fo...          NaN
# 62    Source: U.S. Census Bureau, Population Division          NaN
# 63                        Release Date: December 2022          NaN
#
# [63 rows x 2 columns]

# %%
#We rename the column names and then remove the '.' from the geographic area's name
population_data.columns = ['Geographic Area','Population 2022']
population_data = population_data.drop(0)
population_data['Geographic Area'] = population_data['Geographic Area'].str.lstrip('.')
population_data.head(10)
# Out:
#    Geographic Area  Population 2022
# 1    United States      333287557.0
# 2        Northeast       57040406.0
# 3          Midwest       68787595.0
# 4            South      128716192.0
# 5             West       78743364.0
# 6          Alabama        5074296.0
# 7           Alaska         733583.0
# 8          Arizona        7359197.0
# 9         Arkansas        3045637.0
# 10      California       39029342.0

# %%
# Merge the population data with your list of dictionaries
merged_data = pd.merge(population_data, pd.DataFrame(title_revid_list), left_on='Geographic Area', right_on='state')
merged_data.head(10)
# Out:
#   Geographic Area  Population 2022                  article prediction  \
# 0         Alabama        5074296.0       Abbeville, Alabama          C
# 1         Alabama        5074296.0      Adamsville, Alabama          C
# 2         Alabama        5074296.0         Addison, Alabama          C
# 3         Alabama        5074296.0           Akron, Alabama         GA
# 4         Alabama        5074296.0       Alabaster, Alabama          C
# 5         Alabama        5074296.0     Albertville, Alabama          C
# 6         Alabama        5074296.0  Alexander City, Alabama         GA
# 7         Alabama        5074296.0      Aliceville, Alabama         GA
# 8         Alabama        5074296.0         Allgood, Alabama          C
# 9         Alabama        5074296.0         Altoona, Alabama          C
#
#                      title   lastrevid    state
# 0       Abbeville, Alabama  1171163550  Alabama
# 1      Adamsville, Alabama  1177621427  Alabama
# 2         Addison, Alabama  1168359898  Alabama
# 3           Akron, Alabama  1165909508  Alabama
# 4       Alabaster, Alabama  1179139816  Alabama
# 5     Albertville, Alabama  1179198677  Alabama
# 6  Alexander City, Alabama  1179140073  Alabama
# 7      Aliceville, Alabama  1167792390  Alabama
# 8         Allgood, Alabama  1165909718  Alabama
# 9         Altoona, Alabama  1165909823  Alabama

# %% [markdown]
# The 'region' demarcation within the US is not standardized and fixed. In fact, different US government agencies agglomerate states to define regions as a function of differing goals. For this analysis, we will use the regional and divisional agglomerations as defined by the US Census Bureau. The data for the same can be found in ['US States by Region - US Census Bureau'](https://docs.google.com/spreadsheets/d/14Sjfd_u_7N9SSyQ7bmxfebF_2XpR8QamvmNntKDIQB0/edit?usp=sharing).

# %%
#Pulling the region data from the file uploaded to my drive and processing it to make it usable
region_data = pd.read_excel('/content/drive/My Drive/US States by Region - US Census Bureau.xlsx')
region_data['DIVISION'].fillna(method = 'ffill', inplace = True)
region_data.head(10)
# Out:
#       REGION         DIVISION          STATE
# 0  Northeast              NaN            NaN
# 1        NaN      New England            NaN
# 2        NaN      New England    Connecticut
# 3        NaN      New England          Maine
# 4        NaN      New England  Massachusetts
# 5        NaN      New England  New Hampshire
# 6        NaN      New England   Rhode Island
# 7        NaN      New England        Vermont
# 8        NaN  Middle Atlantic            NaN
# 9        NaN  Middle Atlantic     New Jersey

# %% [markdown]
# Now we merge the data to create the final dataframe to run all the analysis on

# %%
#Merging the previous dataframes with the new region_data
merged_region_data = merged_data.merge(region_data, left_on='state', right_on='STATE', how='left')
merged_region_data = merged_region_data.drop(columns=['Geographic Area','REGION','STATE'])
merged_region_data.head(10)
# Out:
#    Population 2022                  article prediction  \
# 0        5074296.0       Abbeville, Alabama          C
# 1        5074296.0      Adamsville, Alabama          C
# 2        5074296.0         Addison, Alabama          C
# 3        5074296.0           Akron, Alabama         GA
# 4        5074296.0       Alabaster, Alabama          C
# 5        5074296.0     Albertville, Alabama          C
# 6        5074296.0  Alexander City, Alabama         GA
# 7        5074296.0      Aliceville, Alabama         GA
# 8        5074296.0         Allgood, Alabama          C
# 9        5074296.0         Altoona, Alabama          C
#
#                      title   lastrevid    state            DIVISION
# 0       Abbeville, Alabama  1171163550  Alabama  East South Central
# 1      Adamsville, Alabama  1177621427  Alabama  East South Central
# 2         Addison, Alabama  1168359898  Alabama  East South Central
# 3           Akron, Alabama  1165909508  Alabama  East South Central
# 4       Alabaster, Alabama  1179139816  Alabama  East South Central
# 5     Albertville, Alabama  1179198677  Alabama  East South Central
# 6  Alexander City, Alabama  1179140073  Alabama  East South Central
# 7      Aliceville, Alabama  1167792390  Alabama  East South Central
# 8         Allgood, Alabama  1165909718  Alabama  East South Central
# 9         Altoona, Alabama  1165909823  Alabama  East South Central

# %% [markdown]
# # Analysis

# %% [markdown]
# The analysis for this study will consist of calculating total-articles-per-population (a ratio representing the number of articles per person) and high-quality-articles-per-population (a ratio representing the number of high quality articles per person) on a state-by-state and divisional basis. All of these values are 'per capita' ratios.
# For this analysis 'high quality' articles are considered as articles that ORES predicted would be in either the 'FA' (featured article) or 'GA' (good article) classes.
#
# The data is then used to construct six following tables:
# 1. Top 10 US states by coverage: The 10 US states with the highest total articles per capita (in descending order) .
# 2. Bottom 10 US states by coverage: The 10 US states with the lowest total articles per capita (in ascending order) .
# 3. Top 10 US states by high quality: The 10 US states with the highest high quality articles per capita (in descending order) .
# 4. Bottom 10 US states by high quality: The 10 US states with the lowest high quality articles per capita (in ascending order).
# 5. Census divisions by total coverage: A rank ordered list of US census divisions (in descending order) by total articles per capita.
# 6. Census divisions by high quality coverage: Rank ordered list of US census divisions (in descending order) by high quality articles per capita.

# %% [markdown]
# # a) Top 10 US states by coverage: The 10 US states with the highest total articles per capita (in descending order) .

# %%
#First we count the number of articles per state
statewise_count = merged_region_data.groupby('state')['title'].count()
#We calculate the statewise population
statewise_pop = merged_region_data.groupby('state')['Population 2022'].mean()
#Then we calculate the count of articles per capita
statewise_coverage_per_capita = statewise_count/statewise_pop
statewise_coverage_per_capita.sort_values(ascending=False,inplace=True)
top_state_coverage = statewise_coverage_per_capita.to_frame()
#Now we showcase the top 10 US states with the max articles
top_state_coverage = top_state_coverage.rename(columns={0:'Top 10 USA states by coverage'})
top_state_coverage.head(10)
# Out:
#                Top 10 USA states by coverage
# state
# Vermont                             0.000507
# North Dakota                        0.000457
# Maine                               0.000349
# South Dakota                        0.000342
# Iowa                                0.000326
# Alaska                              0.000202
# Pennsylvania                        0.000197
# Michigan                            0.000177
# Wyoming                             0.000170
# New Hampshire                       0.000168

# %% [markdown]
# # b) Bottom 10 US states by coverage: The 10 US states with the lowest total articles per capita (in ascending order) .

# %%
#First we count the number of articles per state
statewise_count = merged_region_data.groupby('state')['title'].count()
#We calculate the statewise population
statewise_pop = merged_region_data.groupby('state')['Population 2022'].mean()
#Then we calculate the count of articles per capita
statewise_coverage_per_capita = statewise_count/statewise_pop
statewise_coverage_per_capita.sort_values(ascending=True,inplace=True)
top_state_coverage = statewise_coverage_per_capita.to_frame()
#Now we showcase the top 10 US states with the max articles
top_state_coverage = top_state_coverage.rename(columns={0:'Bottom 10 USA states by coverage'})
top_state_coverage.head(10)
# Out:
#                 Bottom 10 USA states by coverage
# state
# North Carolina                          0.000005
# Nevada                                  0.000006
# California                              0.000012
# Arizona                                 0.000012
# Virginia                                0.000015
# Oklahoma                                0.000018
# Florida                                 0.000018
# Kansas                                  0.000021
# Maryland                                0.000025
# Wisconsin                               0.000032

# %% [markdown]
# # c) Top 10 US states by high quality: The 10 US states with the highest high quality articles per capita (in descending order) .

# %%
#First we create a column with boolean values with 1 showing high quality artcile and 0 showing otherwise
merged_region_data['high_quality_articles'] = (merged_region_data['prediction'] == 'FA') | (merged_region_data['prediction'] == 'GA')
#We group the high quality articles by state
highest_quality_by_state = merged_region_data.groupby('state')['high_quality_articles'].sum()
#Calculating these sums per capita
highest_quality_by_state_per_capita = highest_quality_by_state/statewise_pop
highest_quality_by_state_per_capita.sort_values(ascending=False,inplace=True)
top_high_qual = highest_quality_by_state_per_capita.to_frame()
top_high_qual = top_high_qual.rename(columns={0:'Top 10 US states with High Quality Articles per Capita'})
top_high_qual.head(10)
# Out:
#                Top 10 US states with High Quality Articles per Capita
# state
# Vermont                                                 0.000070
# Wyoming                                                 0.000067
# South Dakota                                            0.000062
# West Virginia                                           0.000060
# Montana                                                 0.000049
# New Hampshire                                           0.000045
# Pennsylvania                                            0.000044
# Missouri                                                0.000042
# Alaska                                                  0.000042
# New Jersey                                              0.000041

# %% [markdown]
# # d) Bottom 10 US states by high quality: The 10 US states with the lowest high quality articles per capita (in ascending order).

# %%
#We do the same procesure as before but now we will put ascending as True so that we have the bottom 10 states
lowest_quality_by_state = merged_region_data.groupby('state')['high_quality_articles'].sum()
lowest_quality_by_state_per_capita = lowest_quality_by_state/statewise_pop
lowest_quality_by_state_per_capita.sort_values(ascending=True,inplace=True)
low_high_qual = lowest_quality_by_state_per_capita.to_frame()
low_high_qual = low_high_qual.rename(columns={0:'Bottom 10 US states with High Quality Articles per Capita'})
low_high_qual.head(10)
# Out:
#                 Bottom 10 US states with High Quality Articles per Capita
# state
# North Carolina                                           0.000002
# Virginia                                                 0.000002
# Nevada                                                   0.000002
# Arizona                                                  0.000003
# California                                               0.000004
# Florida                                                  0.000005
# New York                                                 0.000006
# Maryland                                                 0.000007
# Kansas                                                   0.000007
# Oklahoma                                                 0.000008

# %% [markdown]
# # e) Census divisions by total coverage: A rank ordered list of US census divisions (in descending order) by total articles per capita.

# %%
# Rank ordered list of US census divisions by total articles per capita
final_df3 = merged_region_data.copy()
articles_per_state = final_df3[['state', 'title']].groupby('state', as_index=False).count()
articles_per_state = pd.DataFrame(articles_per_state)
articles_per_state.head()

state_division_pop = final_df3[['state', 'DIVISION', 'Population 2022']].drop_duplicates()
state_division_pop.head()

articles_per_div_state = pd.merge(state_division_pop, articles_per_state, on='state', how='inner')
articles_per_div_state.head()

grouped_values = articles_per_div_state.groupby('DIVISION', as_index=False)
grouped_values = grouped_values.sum()
grouped_values['articles_per_capita'] = grouped_values['title']/grouped_values['Population 2022']
grouped_values = grouped_values.sort_values(by='articles_per_capita', ascending=False)
grouped_values
# Out:
#              DIVISION  Population 2022  title  articles_per_capita
# 7  West North Central       19721893.0   3574             0.000181
# 4         New England       11503343.0   1433             0.000125
# 0  East North Central       47097779.0   4750             0.000101
# 2     Middle Atlantic       41910858.0   3772             0.000090
# 1  East South Central       19578002.0   1527             0.000078
# 8  West South Central       41685250.0   2098             0.000050
# 3            Mountain       25514320.0   1184             0.000046
# 6      South Atlantic       66781137.0   1846             0.000028
# 5             Pacific       53229044.0   1298             0.000024

# %% [markdown]
# # f) Census divisions by high quality coverage: Rank ordered list of US census divisions (in descending order) by high quality articles per capita.

# %%
# Rank ordered list of US census divisions by high quality articles per capita
final_df4 = merged_region_data.copy()
final_df4 = final_df4[final_df4['prediction'].isin(['FA', 'GA'])]
articles_per_state2 = final_df4[['state', 'title']].groupby('state', as_index=False).count()
articles_per_state2 = pd.DataFrame(articles_per_state2)

state_division_pop2 = final_df4[['state', 'DIVISION', 'Population 2022']].drop_duplicates()

articles_per_div_state2 = pd.merge(state_division_pop2, articles_per_state2, on='state', how='inner')

grouped_values2 = articles_per_div_state2.groupby('DIVISION', as_index=False)
grouped_values2 = grouped_values2.sum()
grouped_values2['articles_per_capita'] = grouped_values2['title']/grouped_values2['Population 2022']
grouped_values2 = grouped_values2.sort_values(by='articles_per_capita', ascending=False)
grouped_values2
# Out:
#              DIVISION  Population 2022  title  articles_per_capita
# 7  West North Central       19721893.0    637             0.000032
# 2     Middle Atlantic       41910858.0   1055             0.000025
# 4         New England       11503343.0    224             0.000019
# 1  East South Central       19578002.0    316             0.000016
# 0  East North Central       47097779.0    715             0.000015
# 8  West South Central       41685250.0    632             0.000015
# 3            Mountain       25514320.0    333             0.000013
# 5             Pacific       53229044.0    489             0.000009
# 6      South Atlantic       66781137.0    525             0.000008
